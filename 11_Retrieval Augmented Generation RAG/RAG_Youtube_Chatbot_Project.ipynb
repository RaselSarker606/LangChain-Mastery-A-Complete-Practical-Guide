# %% [markdown]
# Install libraries

# %%
# !pip install langchain chromadb faiss-cpu sentence-transformers tiktoken pypdf langchain_openai langchain-community
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.25)
# Collecting chromadb
#   Downloading chromadb-1.0.13-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Collecting pypdf
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting langchain_openai
#   Downloading langchain_openai-0.3.24-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.25-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.65)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.45)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.2.2.post1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb) (2.0.2)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-5.1.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.14.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.21.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (1.73.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.16.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-33.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb) (9.1.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.11/dist-packages (from chromadb) (4.24.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /usr/local/lib/python3.11/dist-packages (from langchain_openai) (1.86.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.3.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.34.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.34.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-1.0.13-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 103.1 MB/s eta 0:00:00
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 67.3 MB/s eta 0:00:00
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.2/304.2 kB 28.1 MB/s eta 0:00:00
# Downloading langchain_openai-0.3.24-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.4 MB/s eta 0:00:00
# Downloading langchain_community-0.3.25-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 85.8 MB/s eta 0:00:00
# Downloading bcrypt-4.3.0-cp39-abi3-manylinux_2_34_x86_64.whl (284 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 26.5 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading kubernetes-33.1.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 90.1 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.22.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 100.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 6.7 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.34.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.34.1-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 4.8 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 12.6 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 18.9 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-5.1.0-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 11.4 MB/s eta 0:00:00
# Downloading pybase64-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 7.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 50.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.0 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 19.5 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.6 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 88.4 MB/s eta 0:00:00
# Downloading watchfiles-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (453 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 35.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53803 sha256=c81ff2ced5813c06f9146f20732d84dae14c1b7539a0a42660b1b9bf17858456
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, durationpy, uvloop, python-dotenv, pypdf, pybase64, overrides, opentelemetry-proto, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, mmh3, marshmallow, humanfriendly, httpx-sse, httptools, faiss-cpu, bcrypt, backoff, watchfiles, typing-inspect, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, nvidia-cusparse-cu12, nvidia-cudnn-cu12, coloredlogs, pydantic-settings, opentelemetry-semantic-conventions, onnxruntime, nvidia-cusolver-cu12, kubernetes, dataclasses-json, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, langchain_openai, chromadb, langchain-community
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed backoff-2.2.1 bcrypt-4.3.0 chromadb-1.0.13 coloredlogs-15.0.1 dataclasses-json-0.6.7 durationpy-0.10 faiss-cpu-1.11.0 httptools-0.6.4 httpx-sse-0.4.0 humanfriendly-10.0 kubernetes-33.1.0 langchain-community-0.3.25 langchain_openai-0.3.24 marshmallow-3.26.1 mmh3-5.1.0 mypy-extensions-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnxruntime-1.22.0 opentelemetry-api-1.34.1 opentelemetry-exporter-otlp-proto-common-1.34.1 opentelemetry-exporter-otlp-proto-grpc-1.34.1 opentelemetry-proto-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 overrides-7.7.0 posthog-5.1.0 pybase64-1.4.1 pydantic-settings-2.9.1 pypdf-5.6.0 pypika-0.48.9 python-dotenv-1.1.0 typing-inspect-0.9.0 uvloop-0.21.0 watchfiles-1.1.0

# %%
# !pip install -q youtube-transcript-api faiss-cpu tiktoken python-dotenv

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# # Step 1 (a) - Indexing (Document Ingestion)

# %%
video_id = "Gfr50f6ZBvo" # only the ID, not full URL
try:
    # If you don’t care which language, this returns the “best” one
    transcript_list = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])

    # Flatten it to plain text
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough to interview you well i'll be impressed if if you were i'd be impressed by myself if you were i don't think we're quite up to that yet but uh maybe you're from the future lex if you did would you tell me is that is that a good thing to tell a language model that's tasked with interviewing that it is in fact um ai maybe we're in a kind of meta turing test uh probably probably it would be a good idea not to tell you so it doesn't change your behavior right this is a kind of heisenberg uncertainty principle situation if i told you you behave differently yeah maybe that's what's happening with us of course this is a benchmark from the future where they replay 2022 as a year before ais were good enough yet and now we want to see is it going to pass exactly if i was such a program would you be able to tell do you think so to the touring test question you've talked about the benchmark for solving intelligence what would be the impressive thing you've talked about winning a nobel prize in a system winning a nobel prize but i still return to the touring test as a compelling test the spirit of the touring test is a compelling test yeah the turing test of course it's been unbelievably influential and turing's one of my all-time heroes but i think if you look back at the 1950 papers original paper and read the original you'll see i don't think he meant it to be a rigorous formal test i think it was more like a thought experiment almost a bit of philosophy he was writing if you look at the style of the paper and you can see he didn't specify it very rigorously so for example he didn't specify the knowledge that the expert or judge would have um not you know how much time would they have to investigate this so these important parameters if you were gonna make it uh a true sort of formal test um and you know some by some measures people claimed the turing test passed several you know a decade ago i remember someone claiming that with a with a kind of very bog standard normal uh logic model um because they pretended it was a it was a kid so the the judges thought that the machine you know was was a was a child so um that would be very different from an expert ai person uh interrogating a machine and knowing how it was built and so on so i think um you know we should probably move away from that as a formal test and move more towards a general test where we test the ai capabilities on a range of tasks and see if it reaches human level or above performance on maybe thousands perhaps even millions of tasks eventually and cover the entire sort of cognitive space so i think for its time it was an amazing thought experiment and also 1950s obviously it was barely the dawn of the computer age so of course he only thought about text and now um we have a lot more different inputs so yeah maybe the better thing to test is the generalizability so across multiple tasks but i think it's also possible as as systems like god show that eventually that might map right back to lan ...

# %%
transcript_list
# Out:
# [{'text': 'the following is a conversation with',
#   'start': 0.08,
#   'duration': 3.44},
#  {'text': 'demus hasabis', 'start': 1.76, 'duration': 4.96},
#  {'text': 'ceo and co-founder of deepmind', 'start': 3.52, 'duration': 5.119},
#  {'text': 'a company that has published and builds',
#   'start': 6.72,
#   'duration': 4.48},
#  {'text': 'some of the most incredible artificial',
#   'start': 8.639,
#   'duration': 4.561},
#  {'text': 'intelligence systems in the history of',
#   'start': 11.2,
#   'duration': 4.8},
#  {'text': 'computing including alfred zero that',
#   'start': 13.2,
#   'duration': 3.68},
#  {'text': 'learned', 'start': 16.0, 'duration': 2.96},
#  {'text': 'all by itself to play the game of gold',
#   'start': 16.88,
#   'duration': 4.559},
#  {'text': 'better than any human in the world and',
#   'start': 18.96,
#   'duration': 5.6},
#  {'text': 'alpha fold two that solved protein',
#   'start': 21.439,
#   'duration': 4.241},
#  {'text': 'folding', 'start': 24.56, 'duration': 4.16},
#  {'text': 'both tasks considered nearly impossible',
#   'start': 25.68,
#   'duration': 5.439},
#  {'text': 'for a very long time', 'start': 28.72, 'duration': 4.4},
#  {'text': 'demus is widely considered to be one of',
#   'start': 31.119,
#   'duration': 4.481},
#  {'text': 'the most brilliant and impactful humans',
#   'start': 33.12,
#   'duration': 4.0},
#  {'text': 'in the history of artificial', 'start': 35.6, 'duration': 4.24},
#  {'text': 'intelligence and science and engineering',
#   'start': 37.12,
#   'duration': 4.0},
#  {'text': 'in general', 'start': 39.84, 'duration': 3.92},
#  {'text': 'this was truly an honor and a pleasure',
#   'start': 41.12,
#   'duration': 4.959},
#  {'text': 'for me to finally sit down with him for',
#   'start': 43.76,
#   'duration': 4.799},
#  {'text': "this conversation and i'm sure we will",
#   'start': 46.079,
#   'duration': 5.361},
#  {'text': 'talk many times again in the future',
#   'start': 48.559,
#   'duration': 4.721},
#  {'text': 'this is the lex friedman podcast to',
#   'start': 51.44,
#   'duration': 4.0},
#  {'text': 'support it please check out our sponsors',
#   'start': 53.28,
#   'duration': 4.959},
#  {'text': 'in the description and now dear friends',
#   'start': 55.44,
#   'duration': 4.16},
#  {'text': "here's demis", 'start': 58.239, 'duration': 3.201},
#  {'text': 'hassabis', 'start': 59.6, 'duration': 3.36},
#  {'text': "let's start with a bit of a personal",
#   'start': 61.44,
#   'duration': 2.48},
#  {'text': 'question', 'start': 62.96, 'duration': 3.839},
#  {'text': 'am i an ai program you wrote to', 'start': 63.92, 'duration': 4.8},
#  {'text': 'interview people until i get good enough',
#   'start': 66.799,
#   'duration': 4.161},
#  {'text': 'to interview you', 'start': 68.72, 'duration': 4.24},
#  {'text': "well i'll be impressed if if you were",
#   'start': 70.96,
#   'duration': 3.839},
#  {'text': "i'd be impressed by myself if you were i",
#   'start': 72.96,
#   'duration': 3.44},
#  {'text': "don't think we're quite up to that yet",
#   'start': 74.799,
#   'duration': 3.921},
#  {'text': "but uh maybe you're from the future lex",
#   'start': 76.4,
#   'duration': 4.48},
#  {'text': 'if you did would you tell me is that is',
#   'start': 78.72,
#   'duration': 3.84},
#  {'text': 'that a good thing to tell a language',
#   'start': 80.88,
#   'duration': 4.08},
#  {'text': "model that's tasked with interviewing",
#   'start': 82.56,
#   'duration': 5.199},
#  {'text': "that it is in fact um ai maybe we're in",
#   'start': 84.96,
#   'duration': 5.28},
#  {'text': 'a kind of meta turing test uh probably',
#   'start': 87.759,
#   'duration': 4.081},
#  {'text': 'probably it would be a good idea not to',
#   'start': 90.24,
#   'duration': 2.96},
#  {'text': "tell you so it doesn't change your",
#   'start': 91.84,
#   'duration': 2.88},
#  {'text': 'behavior right this is a kind of', 'start': 93.2, 'duration': 3.2},
#  {'text': 'heisenberg uncertainty principle',
#   'start': 94.72,
#   'duration': 3.359},
#  {'text': 'situation if i told you you behave',
#   'start': 96.4,
#   'duration': 3.12},
#  {'text': "differently yeah maybe that's what's",
#   'start': 98.079,
#   'duration': 3.201},
#  {'text': 'happening with us of course this is a',
#   'start': 99.52,
#   'duration': 4.0},
#  {'text': 'benchmark from the future where they',
#   'start': 101.28,
#   'duration': 6.56},
#  {'text': 'replay 2022 as a year before ais were',
#   'start': 103.52,
#   'duration': 7.36},
#  {'text': 'good enough yet and now we want to see',
#   'start': 107.84,
#   'duration': 5.919},
#  {'text': 'is it going to pass exactly', 'start': 110.88, 'duration': 4.559},
#  {'text': 'if i was such a', 'start': 113.759, 'duration': 3.36},
#  {'text': 'program would you be able to tell do you',
#   'start': 115.439,
#   'duration': 4.481},
#  {'text': 'think so to the touring test question',
#   'start': 117.119,
#   'duration': 5.921},
#  {'text': "you've talked about", 'start': 119.92, 'duration': 3.12},
#  {'text': 'the benchmark for solving intelligence',
#   'start': 123.2,
#   'duration': 3.919},
#  {'text': 'what would be the impressive thing',
#   'start': 125.68,
#   'duration': 2.96},
#  {'text': "you've talked about winning a nobel",
#   'start': 127.119,
#   'duration': 4.161},
#  {'text': 'prize in a system winning a nobel prize',
#   'start': 128.64,
#   'duration': 4.72},
#  {'text': 'but i still return to the touring test',
#   'start': 131.28,
#   'duration': 3.76},
#  {'text': 'as a compelling test the spirit of the',
#   'start': 133.36,
#   'duration': 3.76},
#  {'text': 'touring test is a compelling test',
#   'start': 135.04,
#   'duration': 3.76},
#  {'text': "yeah the turing test of course it's been",
#   'start': 137.12,
#   'duration': 3.52},
#  {'text': "unbelievably influential and turing's",
#   'start': 138.8,
#   'duration': 4.24},
#  {'text': 'one of my all-time heroes but i think if',
#   'start': 140.64,
#   'duration': 4.239},
#  {'text': 'you look back at the 1950 papers',
#   'start': 143.04,
#   'duration': 3.839},
#  {'text': 'original paper and read the original',
#   'start': 144.879,
#   'duration': 4.0},
#  {'text': "you'll see i don't think he meant it to",
#   'start': 146.879,
#   'duration': 4.321},
#  {'text': 'be a rigorous formal test i think it was',
#   'start': 148.879,
#   'duration': 4.161},
#  {'text': 'more like a thought experiment almost a',
#   'start': 151.2,
#   'duration': 3.52},
#  {'text': 'bit of philosophy he was writing if you',
#   'start': 153.04,
#   'duration': 3.52},
#  {'text': 'look at the style of the paper and you',
#   'start': 154.72,
#   'duration': 3.28},
#  {'text': "can see he didn't specify it very",
#   'start': 156.56,
#   'duration': 3.52},
#  {'text': "rigorously so for example he didn't",
#   'start': 158.0,
#   'duration': 4.879},
#  {'text': 'specify the knowledge that the expert or',
#   'start': 160.08,
#   'duration': 5.439},
#  {'text': 'judge would have um not you know how',
#   'start': 162.879,
#   'duration': 4.801},
#  {'text': 'much time would they have to investigate',
#   'start': 165.519,
#   'duration': 4.0},
#  {'text': 'this so these important parameters if',
#   'start': 167.68,
#   'duration': 4.48},
#  {'text': 'you were gonna make it uh a true sort of',
#   'start': 169.519,
#   'duration': 3.921},
#  {'text': 'formal test', 'start': 172.16, 'duration': 4.32},
#  {'text': 'um and you know some by some measures',
#   'start': 173.44,
#   'duration': 4.879},
#  {'text': 'people claimed the turing test passed',
#   'start': 176.48,
#   'duration': 3.36},
#  {'text': 'several you know a decade ago i remember',
#   'start': 178.319,
#   'duration': 3.2},
#  {'text': 'someone claiming that with a with a kind',
#   'start': 179.84,
#   'duration': 4.56},
#  {'text': 'of very bog standard normal uh',
#   'start': 181.519,
#   'duration': 5.44},
#  {'text': 'logic model um because they pretended it',
#   'start': 184.4,
#   'duration': 5.199},
#  {'text': 'was a it was a kid so the the judges',
#   'start': 186.959,
#   'duration': 4.721},
#  {'text': 'thought that the machine you know was',
#   'start': 189.599,
#   'duration': 5.121},
#  {'text': 'was a was a child so um that would be',
#   'start': 191.68,
#   'duration': 5.52},
#  {'text': 'very different from an expert ai person',
#   'start': 194.72,
#   'duration': 4.32},
#  {'text': 'uh interrogating a machine and knowing',
#   'start': 197.2,
#   'duration': 5.119},
#  {'text': 'how it was built and so on so i think um',
#   'start': 199.04,
#   'duration': 4.64},
#  {'text': 'you know we should probably move away',
#   'start': 202.319,
#   'duration': 4.081},
#  {'text': 'from that as a formal test and move more',
#   'start': 203.68,
#   'duration': 5.839},
#  {'text': 'towards a general test where we test the',
#   'start': 206.4,
#   'duration': 5.759},
#  {'text': 'ai capabilities on a range of tasks and',
#   'start': 209.519,
#   'duration': 5.121},
#  {'text': 'see if it reaches human level or above',
#   'start': 212.159,
#   'duration': 5.121},
#  {'text': 'performance on maybe thousands perhaps',
#   'start': 214.64,
#   'duration': 4.64},
#  {'text': 'even millions of tasks eventually and',
#   'start': 217.28,
#   'duration': 4.56},
#  {'text': 'cover the entire sort of cognitive space',
#   'start': 219.28,
#   'duration': 4.08},
#  {'text': 'so i think', 'start': 221.84, 'duration': 3.119},
#  {'text': 'for its time it was an amazing thought',
#   'start': 223.36,
#   'duration': 3.92},
#  {'text': 'experiment and also 1950s obviously it',
#   'start': 224.959,
#   'duration': 4.321},
#  {'text': 'was barely the dawn of the computer age',
#   'start': 227.28,
#   'duration': 4.08},
#  {'text': 'so of course he only thought about text',
#   'start': 229.28,
#   'duration': 4.239},
#  {'text': 'and now um we have a lot more different',
#   'start': 231.36,
#   'duration': 3.12},
#  {'text': 'inputs', 'start': 233.519, 'duration': 3.44},
#  {'text': 'so yeah maybe the better thing to test',
#   'start': 234.48,
#   'duration': 4.319},
#  {'text': 'is the generalizability so across',
#   'start': 236.959,
#   'duration': 4.0},
#  {'text': "multiple tasks but i think it's also",
#   'start': 238.799,
#   'duration': 5.761},
#  {'text': 'possible as as systems like god show',
#   'start': 240.959,
#   'duration': 4.56},
#  {'text': 'that', 'start': 244.56, 'duration': 2.879},
#  {'text': 'eventually that might map right back to',
#   'start': 245.519,
#   'duration': 3.681},
#  {'text': 'language so you might be able to',
#   'start': 247.439,
#   'duration': 4.08},
#  {'text': 'demonstrate your ability to generalize',
#   'start': 249.2,
#   'duration': 3.92},
#  {'text': 'across tasks', 'start': 251.519, 'duration': 3.841},
#  {'text': 'by then communicating your ability to',
#   'start': 253.12,
#   'duration': 4.399},
#  {'text': 'generalize across tasks which is kind of',
#   'start': 255.36,
#   'duration': 3.68},
#  {'text': 'what we do through conversation anyway',
#   'start': 257.519,
#   'duration': 3.201},
#  {'text': 'when we jump around', 'start': 259.04, 'duration': 3.52},
#  {'text': "ultimately what's in there in that",
#   'start': 260.72,
#   'duration': 4.24},
#  {'text': 'conversation is not just you moving',
#   'start': 262.56,
#   'duration': 4.32},
#  {'text': 'around knowledge', 'start': 264.96, 'duration': 4.16},
#  {'text': "it's you moving around like these",
#   'start': 266.88,
#   'duration': 4.879},
#  {'text': 'entirely different modalities of',
#   'start': 269.12,
#   'duration': 5.84},
#  {'text': 'understanding that ultimately map to',
#   'start': 271.759,
#   'duration': 5.121},
#  {'text': 'your ability to', 'start': 274.96, 'duration': 4.48},
#  {'text': 'to uh operate successfully in all these',
#   'start': 276.88,
#   'duration': 5.599},
#  {'text': 'domains which you can think of as tasks',
#   'start': 279.44,
#   'duration': 5.52},
#  {'text': 'yeah i think certainly we as humans use',
#   'start': 282.479,
#   'duration': 4.961},
#  {'text': 'language as our main generalization',
#   'start': 284.96,
#   'duration': 5.04},
#  {'text': 'communication tool so i think we end up',
#   'start': 287.44,
#   'duration': 4.88},
#  {'text': 'thinking in language and expressing our',
#   'start': 290.0,
#   'duration': 4.96},
#  {'text': "solutions in language um so it's going",
#   'start': 292.32,
#   'duration': 4.08},
#  {'text': 'to be very powerful', 'start': 294.96, 'duration': 5.12},
#  {'text': 'uh uh mode in which to uh explain you',
#   'start': 296.4,
#   'duration': 5.2},
#  {'text': "know the system to explain what it's",
#   'start': 300.08,
#   'duration': 4.8},
#  {'text': "doing um but i don't think it's the only",
#   'start': 301.6,
#   'duration': 6.56},
#  {'text': 'uh uh modality that matters so i think',
#   'start': 304.88,
#   'duration': 4.72},
#  {'text': "there's gonna be a lot of you know",
#   'start': 308.16,
#   'duration': 2.72},
#  {'text': "there's there's a lot of different ways",
#   'start': 309.6,
#   'duration': 4.24},
#  {'text': 'to express uh capabilities uh other than',
#   'start': 310.88,
#   'duration': 4.56},
#  {'text': 'just language', 'start': 313.84, 'duration': 2.88},
#  {'text': 'yeah visual', 'start': 315.44, 'duration': 4.479},
#  {'text': 'robotics body language', 'start': 316.72, 'duration': 4.319},
#  {'text': 'um', 'start': 319.919, 'duration': 3.041},
#  {'text': 'yeah action is the interactive aspect of',
#   'start': 321.039,
#   'duration': 3.761},
#  {'text': "all that that's all part of it but",
#   'start': 322.96,
#   'duration': 3.28},
#  {'text': "what's interesting with gato is that",
#   'start': 324.8,
#   'duration': 4.08},
#  {'text': "it's a it's it's it's sort of pushing",
#   'start': 326.24,
#   'duration': 4.48},
#  {'text': 'prediction to the maximum in terms of',
#   'start': 328.88,
#   'duration': 3.84},
#  {'text': 'like you know mapping arbitrary',
#   'start': 330.72,
#   'duration': 4.08},
#  {'text': 'sequences to other sequences and sort of',
#   'start': 332.72,
#   'duration': 3.36},
#  {'text': "just predicting what's going to happen",
#   'start': 334.8,
#   'duration': 3.839},
#  {'text': 'next so prediction seems to be', 'start': 336.08, 'duration': 4.88},
#  {'text': 'fundamental to intelligence', 'start': 338.639, 'duration': 4.161},
#  {'text': "and what you're predicting", 'start': 340.96, 'duration': 4.0},
#  {'text': "doesn't so much matter yeah it seems",
#   'start': 342.8,
#   'duration': 3.839},
#  {'text': 'like you can generalize that quite well',
#   'start': 344.96,
#   'duration': 3.28},
#  {'text': 'so obviously language models predict the',
#   'start': 346.639,
#   'duration': 4.241},
#  {'text': 'next word um gato predicts potentially',
#   'start': 348.24,
#   'duration': 6.0},
#  {'text': "any uh action or any token uh and it's",
#   'start': 350.88,
#   'duration': 4.72},
#  {'text': "just the beginning really it's our most",
#   'start': 354.24,
#   'duration': 3.76},
#  {'text': 'general agent one could call it so far',
#   'start': 355.6,
#   'duration': 4.4},
#  {'text': 'but um you know that itself can be',
#   'start': 358.0,
#   'duration': 3.6},
#  {'text': "scaled up massively more than we've done",
#   'start': 360.0,
#   'duration': 3.039},
#  {'text': "so far obviously we're in the in the",
#   'start': 361.6,
#   'duration': 4.08},
#  {'text': 'middle of doing that but the big part of',
#   'start': 363.039,
#   'duration': 6.081},
#  {'text': 'solving agi is creating benchmarks that',
#   'start': 365.68,
#   'duration': 6.48},
#  {'text': 'help us get closer and closer sort of',
#   'start': 369.12,
#   'duration': 4.799},
#  {'text': 'creating benchmarks that test the',
#   'start': 372.16,
#   'duration': 3.599},
#  {'text': "journalizability and it's just still",
#   'start': 373.919,
#   'duration': 4.881},
#  {'text': 'interesting that this fella alan turing',
#   'start': 375.759,
#   'duration': 5.601},
#  {'text': 'was one of the first and probably still',
#   'start': 378.8,
#   'duration': 4.959},
#  {'text': 'one of the only people that was trying',
#   'start': 381.36,
#   'duration': 4.24},
#  {'text': 'maybe philosophically but was trying to',
#   'start': 383.759,
#   'duration': 3.44},
#  {'text': 'formulate a benchmark that could be',
#   'start': 385.6,
#   'duration': 3.2},
#  {'text': 'followed it is', 'start': 387.199, 'duration': 4.081},
#  {'text': "even though it's it's fuzzy it's still",
#   'start': 388.8,
#   'duration': 4.08},
#  {'text': 'sufficiently rigorous to where you can',
#   'start': 391.28,
#   'duration': 3.84},
#  {'text': 'run that test and i still think',
#   'start': 392.88,
#   'duration': 4.159},
#  {'text': 'something like the touring test will at',
#   'start': 395.12,
#   'duration': 3.519},
#  {'text': 'the end of the day', 'start': 397.039, 'duration': 3.361},
#  {'text': 'be the thing that truly', 'start': 398.639, 'duration': 3.84},
#  {'text': 'impresses other humans', 'start': 400.4, 'duration': 4.239},
#  {'text': 'so that you can have a close friend',
#   'start': 402.479,
#   'duration': 3.921},
#  {'text': "who's an ai system", 'start': 404.639, 'duration': 3.601},
#  {'text': 'for that friend to be a good friend',
#   'start': 406.4,
#   'duration': 4.0},
#  {'text': "they're going to have to be able to",
#   'start': 408.24,
#   'duration': 4.799},
#  {'text': 'uh play starcraft', 'start': 410.4, 'duration': 4.239},
#  {'text': "and they're going to have to do all of",
#   'start': 413.039,
#   'duration': 5.041},
#  {'text': 'these tasks um get you a beer so the',
#   'start': 414.639,
#   'duration': 5.28},
#  {'text': 'robotics tasks', 'start': 418.08, 'duration': 5.04},
#  {'text': 'uh play games with you use language',
#   'start': 419.919,
#   'duration': 5.84},
#  {'text': 'humor all those kinds of things but that',
#   'start': 423.12,
#   'duration': 4.799},
#  {'text': 'ultimately can boil down to language it',
#   'start': 425.759,
#   'duration': 4.401},
#  {'text': 'feels like not in terms of the ai',
#   'start': 427.919,
#   'duration': 4.56},
#  {'text': 'community but in terms of the actual',
#   'start': 430.16,
#   'duration': 4.159},
#  {'text': 'impact of general intelligence on the',
#   'start': 432.479,
#   'duration': 3.681},
#  {'text': 'world it feels like language will be the',
#   'start': 434.319,
#   'duration': 4.641},
#  {'text': 'place where it truly shines i think so',
#   'start': 436.16,
#   'duration': 4.72},
#  {'text': "because it's such an important kind of",
#   'start': 438.96,
#   'duration': 4.079},
#  {'text': "input output for us i think you're right",
#   'start': 440.88,
#   'duration': 4.0},
#  {'text': 'i think the turing test that what the',
#   'start': 443.039,
#   'duration': 4.241},
#  {'text': 'the kind of the the philosophy behind it',
#   'start': 444.88,
#   'duration': 5.36},
#  {'text': 'which is the idea of can can a machine',
#   'start': 447.28,
#   'duration': 7.6},
#  {'text': 'mimic the behaviors of a human and men',
#   'start': 450.24,
#   'duration': 6.799},
#  {'text': 'and i would say wider than just language',
#   'start': 454.88,
#   'duration': 3.759},
#  {'text': 'and text', 'start': 457.039, 'duration': 3.521},
#  {'text': 'then you know in terms of actions and',
#   'start': 458.639,
#   'duration': 3.601},
#  {'text': 'everything else creativity all these',
#   'start': 460.56,
#   'duration': 4.079},
#  {'text': 'things then um if it can sort of match',
#   'start': 462.24,
#   'duration': 5.04},
#  {'text': 'or exceed human cognitive capabilities',
#   'start': 464.639,
#   'duration': 4.481},
#  {'text': 'then i think we have a you know true',
#   'start': 467.28,
#   'duration': 3.44},
#  {'text': 'intelligence so i thought from that',
#   'start': 469.12,
#   'duration': 3.359},
#  {'text': "perspective you're right i think he did",
#   'start': 470.72,
#   'duration': 5.12},
#  {'text': 'formulate the right uh kind of uh setup',
#   'start': 472.479,
#   'duration': 5.361},
#  {'text': "i just i think there'll be a kind of",
#   'start': 475.84,
#   'duration': 3.359},
#  {'text': 'humor', 'start': 477.84, 'duration': 3.28},
#  {'text': 'in the ai systems of the future looking',
#   'start': 479.199,
#   'duration': 4.241},
#  {'text': 'back to this conversation', 'start': 481.12, 'duration': 4.88},
#  {'text': 'and thinking about the touring test',
#   'start': 483.44,
#   'duration': 5.12},
#  {'text': 'and uh also thinking about', 'start': 486.0, 'duration': 4.319},
#  {'text': 'by that time they would know which year',
#   'start': 488.56,
#   'duration': 4.639},
#  {'text': 'they were finally able to sort of cross',
#   'start': 490.319,
#   'duration': 4.241},
#  {'text': 'the threshold of human level', 'start': 493.199, 'duration': 3.921},
#  {'text': 'intelligence and think', 'start': 494.56, 'duration': 4.319},
#  {'text': 'how funny it is that we humans were',
#   'start': 497.12,
#   'duration': 2.72},
#  {'text': 'still', 'start': 498.879, 'duration': 3.44},
#  {'text': 'confused about this whole problem',
#   'start': 499.84,
#   'duration': 4.72},
#  {'text': 'that has been long ago been solved',
#   'start': 502.319,
#   'duration': 4.0},
#  {'text': 'well hello to the ai agents of the',
#   'start': 504.56,
#   'duration': 4.8},
#  {'text': 'future anyway so going back to your',
#   'start': 506.319,
#   'duration': 4.961},
#  {'text': 'to your journey when did you fall in',
#   'start': 509.36,
#   'duration': 4.239},
#  {'text': 'love with programming first', 'start': 511.28, 'duration': 4.16},
#  {'text': "well it's pretty uh pretty young age",
#   'start': 513.599,
#   'duration': 3.761},
#  {'text': 'actually so um', 'start': 515.44, 'duration': 4.399},
#  {'text': 'you know i started off uh actually games',
#   'start': 517.36,
#   'duration': 4.479},
#  {'text': 'was my first love so starting to play',
#   'start': 519.839,
#   'duration': 3.76},
#  {'text': 'chess when i was around four years old',
#   'start': 521.839,
#   'duration': 3.761},
#  {'text': 'and then um it was actually with',
#   'start': 523.599,
#   'duration': 4.321},
#  {'text': 'winnings from a chess competition that i',
#   'start': 525.6,
#   'duration': 4.0},
#  {'text': 'managed to buy my first chess computer',
#   'start': 527.92,
#   'duration': 2.88},
#  {'text': 'when i was about eight years old it was',
#   'start': 529.6,
#   'duration': 3.44},
#  {'text': 'a zx spectrum which was hugely popular',
#   'start': 530.8,
#   'duration': 3.84},
#  {'text': 'in the uk at the time', 'start': 533.04, 'duration': 4.32},
#  {'text': "and uh it's amazing machine because i",
#   'start': 534.64,
#   'duration': 4.639},
#  {'text': 'think it trained a whole generation of',
#   'start': 537.36,
#   'duration': 4.08},
#  {'text': 'programmers in the uk because it was so',
#   'start': 539.279,
#   'duration': 3.761},
#  {'text': 'accessible you know you literally',
#   'start': 541.44,
#   'duration': 3.12},
#  {'text': 'switched it on and there was the basic',
#   'start': 543.04,
#   'duration': 4.0},
#  {'text': 'prompt and you could just get going and',
#   'start': 544.56,
#   'duration': 4.24},
#  {'text': "um my parents didn't really know",
#   'start': 547.04,
#   'duration': 3.6},
#  {'text': 'anything about computers so but because',
#   'start': 548.8,
#   'duration': 3.68},
#  {'text': 'it was my money from a chess competition',
#   'start': 550.64,
#   'duration': 4.48},
#  {'text': 'i could i could say i i wanted to buy it',
#   'start': 552.48,
#   'duration': 4.479},
#  {'text': 'uh and then you know i just went to',
#   'start': 555.12,
#   'duration': 5.04},
#  {'text': 'bookstores got books on programming and',
#   'start': 556.959,
#   'duration': 5.601},
#  {'text': 'um started typing in you know the',
#   'start': 560.16,
#   'duration': 4.72},
#  {'text': 'programming code and and then of course',
#   'start': 562.56,
#   'duration': 4.08},
#  {'text': 'um once you start doing that you start',
#   'start': 564.88,
#   'duration': 3.28},
#  {'text': 'adjusting it and then making your own',
#   'start': 566.64,
#   'duration': 3.44},
#  {'text': "games and that's when i fell in love",
#   'start': 568.16,
#   'duration': 3.359},
#  {'text': 'with computers and realized that they',
#   'start': 570.08,
#   'duration': 5.12},
#  {'text': 'were a very magical device um in a way i',
#   'start': 571.519,
#   'duration': 4.88},
#  {'text': 'kind of i would have been able to',
#   'start': 575.2,
#   'duration': 2.72},
#  {'text': 'explain this at the time but i felt that',
#   'start': 576.399,
#   'duration': 3.041},
#  {'text': 'they were sort of almost a magical',
#   'start': 577.92,
#   'duration': 3.76},
#  {'text': 'extension of your mind i always had this',
#   'start': 579.44,
#   'duration': 3.76},
#  {'text': "feeling and i've always loved this about",
#   'start': 581.68,
#   'duration': 3.36},
#  {'text': 'computers that you can set them off',
#   'start': 583.2,
#   'duration': 4.24},
#  {'text': 'doing something some task for you you',
#   'start': 585.04,
#   'duration': 4.32},
#  {'text': 'can go to sleep come back the next day',
#   'start': 587.44,
#   'duration': 2.959},
#  {'text': "and it's solved", 'start': 589.36, 'duration': 3.84},
#  {'text': 'um you know that feels magical to me so',
#   'start': 590.399,
#   'duration': 4.401},
#  {'text': 'i mean all machines do that to some',
#   'start': 593.2,
#   'duration': 3.68},
#  {'text': 'extent they all enhance our natural',
#   'start': 594.8,
#   'duration': 3.84},
#  {'text': 'capabilities obviously cars make us',
#   'start': 596.88,
#   'duration': 4.16},
#  {'text': 'allow us to move faster than we can run',
#   'start': 598.64,
#   'duration': 4.879},
#  {'text': 'but this was a machine to extend the',
#   'start': 601.04,
#   'duration': 3.359},
#  {'text': 'mind', 'start': 603.519, 'duration': 3.601},
#  {'text': 'and and then of course ai is the',
#   'start': 604.399,
#   'duration': 4.88},
#  {'text': 'ultimate expression of what a machine',
#   'start': 607.12,
#   'duration': 4.959},
#  {'text': 'may be able to do or learn so',
#   'start': 609.279,
#   'duration': 4.641},
#  {'text': 'very naturally for me that thought',
#   'start': 612.079,
#   'duration': 3.841},
#  {'text': 'extended into into ai quite quickly',
#   'start': 613.92,
#   'duration': 4.479},
#  {'text': 'remember the the programming language',
#   'start': 615.92,
#   'duration': 3.84},
#  {'text': 'that was first', 'start': 618.399, 'duration': 2.641},
#  {'text': 'started', 'start': 619.76, 'duration': 2.72},
#  {'text': 'special to the machine no it was just',
#   'start': 621.04,
#   'duration': 2.96},
#  {'text': 'the base it was just i think it was just',
#   'start': 622.48,
#   'duration': 3.599},
#  {'text': "basic uh on the zx spectrum i don't know",
#   'start': 624.0,
#   'duration': 3.92},
#  {'text': 'what specific form it was and then later',
#   'start': 626.079,
#   'duration': 5.041},
#  {'text': 'on i got a commodore amiga which uh',
#   'start': 627.92,
#   'duration': 5.2},
#  {'text': "was a fantastic machine no you're just",
#   'start': 631.12,
#   'duration': 3.92},
#  {'text': 'showing off so yeah well lots of my',
#   'start': 633.12,
#   'duration': 4.0},
#  {'text': "friends had atari st's and i i managed",
#   'start': 635.04,
#   'duration': 3.76},
#  {'text': 'to get amigas it was a bit more powerful',
#   'start': 637.12,
#   'duration': 3.839},
#  {'text': 'and uh and that was incredible and used',
#   'start': 638.8,
#   'duration': 5.2},
#  {'text': 'to do um programming in assembler and',
#   'start': 640.959,
#   'duration': 5.921},
#  {'text': 'and uh also amos basic this this',
#   'start': 644.0,
#   'duration': 4.64},
#  {'text': 'specific form of basic it was incredible',
#   'start': 646.88,
#   'duration': 4.0},
#  {'text': 'actually as well all my coding skills',
#   'start': 648.64,
#   'duration': 4.48},
#  {'text': 'and when did you fall in love with ai so',
#   'start': 650.88,
#   'duration': 4.56},
#  {'text': 'when did you first', 'start': 653.12, 'duration': 3.92},
#  {'text': 'start to gain an understanding that you',
#   'start': 655.44,
#   'duration': 4.079},
#  {'text': 'can not just write programs that',
#   'start': 657.04,
#   'duration': 4.479},
#  {'text': 'do some mathematical operations for you',
#   'start': 659.519,
#   'duration': 4.961},
#  {'text': "while you sleep but something that's",
#   'start': 661.519,
#   'duration': 4.88},
#  {'text': 'a keen to', 'start': 664.48, 'duration': 4.24},
#  {'text': 'bringing an entity to life', 'start': 666.399, 'duration': 3.201},
#  {'text': 'sort of', 'start': 668.72, 'duration': 3.04},
#  {'text': 'a thing that can figure out something',
#   'start': 669.6,
#   'duration': 4.16},
#  {'text': 'more complicated than uh', 'start': 671.76, 'duration': 4.0},
#  {'text': 'than a simple mathematical operation',
#   'start': 673.76,
#   'duration': 3.759},
#  {'text': 'yeah so there was a few stages for me',
#   'start': 675.76,
#   'duration': 4.16},
#  {'text': 'all while i was very young so first of',
#   'start': 677.519,
#   'duration': 4.241},
#  {'text': 'all as i was trying to improve at',
#   'start': 679.92,
#   'duration': 3.44},
#  {'text': 'playing chess i was captaining various',
#   'start': 681.76,
#   'duration': 3.199},
#  {'text': 'england junior chess teams and at the',
#   'start': 683.36,
#   'duration': 3.28},
#  {'text': 'time when i was about you know maybe 10',
#   'start': 684.959,
#   'duration': 3.44},
#  {'text': '11 years old i was gonna become a',
#   'start': 686.64,
#   'duration': 3.12},
#  {'text': 'professional chess player that was my',
#   'start': 688.399,
#   'duration': 2.241},
#  {'text': 'first', 'start': 689.76, 'duration': 4.319},
#  {'text': 'thought um that dream was there sure she',
#   'start': 690.64,
#   'duration': 5.04},
#  {'text': 'tried to get to the highest level yeah',
#   'start': 694.079,
#   'duration': 4.241},
#  {'text': 'so i was um you know i got to when i was',
#   'start': 695.68,
#   'duration': 4.32},
#  {'text': 'about 12 years old i got to master stand',
#   'start': 698.32,
#   'duration': 3.199},
#  {'text': 'and i was second highest rated player in',
#   'start': 700.0,
#   'duration': 3.279},
#  {'text': 'the world to judith polgar who obviously',
#   'start': 701.519,
#   'duration': 4.161},
#  {'text': 'ended up being an amazing chess player',
#   'start': 703.279,
#   'duration': 6.161},
#  {'text': "and uh world women's champion and when i",
#   'start': 705.68,
#   'duration': 5.2},
#  {'text': 'was trying to improve at chess where you',
#   'start': 709.44,
#   'duration': 2.959},
#  {'text': 'know what you do is you obviously first',
#   'start': 710.88,
#   'duration': 2.88},
#  {'text': "of all you're trying to improve your own",
#   'start': 712.399,
#   'duration': 4.56},
#  {'text': 'thinking processes so that leads you to',
#   'start': 713.76,
#   'duration': 4.72},
#  {'text': 'thinking about thinking how is your',
#   'start': 716.959,
#   'duration': 3.601},
#  {'text': 'brain coming up with these ideas why is',
#   'start': 718.48,
#   'duration': 4.479},
#  {'text': 'it making mistakes how can you how can',
#   'start': 720.56,
#   'duration': 4.16},
#  {'text': 'you improve that thought process but the',
#   'start': 722.959,
#   'duration': 3.921},
#  {'text': 'second thing is that you it was just the',
#   'start': 724.72,
#   'duration': 4.239},
#  {'text': 'beginning this was like in the in the',
#   'start': 726.88,
#   'duration': 4.399},
#  {'text': 'early 80s mid 80s of chess computers if',
#   'start': 728.959,
#   'duration': 3.68},
#  {'text': 'you remember they were physical boards',
#   'start': 731.279,
#   'duration': 2.881},
#  {'text': 'like the one we have in front of us and',
#   'start': 732.639,
#   'duration': 3.361},
#  {'text': 'you pressed down the you know the',
#   'start': 734.16,
#   'duration': 4.16},
#  {'text': 'squares and i think kasparov had a',
#   'start': 736.0,
#   'duration': 5.279},
#  {'text': 'branded version of it that i i i got and',
#   'start': 738.32,
#   'duration': 5.04},
#  {'text': "um you were you know used to they're not",
#   'start': 741.279,
#   'duration': 3.521},
#  {'text': 'as strong as they are today but they',
#   'start': 743.36,
#   'duration': 3.2},
#  {'text': 'were they were pretty strong and you',
#   'start': 744.8,
#   'duration': 4.4},
#  {'text': 'used to practice against them um to try',
#   'start': 746.56,
#   'duration': 4.24},
#  {'text': 'and improve your openings and other',
#   'start': 749.2,
#   'duration': 3.199},
#  {'text': 'things and so i remember i think i',
#   'start': 750.8,
#   'duration': 2.88},
#  {'text': 'probably got my first one i was around',
#   'start': 752.399,
#   'duration': 4.161},
#  {'text': '11 or 12. and i remember thinking um',
#   'start': 753.68,
#   'duration': 4.32},
#  {'text': 'this is amazing you know how how has',
#   'start': 756.56,
#   'duration': 4.32},
#  {'text': 'someone programmed uh uh this this chess',
#   'start': 758.0,
#   'duration': 5.76},
#  {'text': 'board to play chess uh and uh it was',
#   'start': 760.88,
#   'duration': 4.959},
#  {'text': 'very formative book i bought which was',
#   'start': 763.76,
#   'duration': 4.079},
#  {'text': 'called the chess computer handbook by',
#   'start': 765.839,
#   'duration': 4.481},
#  {'text': 'david levy which came out in 1984 or',
#   'start': 767.839,
#   'duration': 3.521},
#  {'text': 'something so i must have got it when i',
#   'start': 770.32,
#   'duration': 3.84},
#  {'text': 'was about 11 12 and it explained fully',
#   'start': 771.36,
#   'duration': 4.8},
#  {'text': 'how these chess programs were made i',
#   'start': 774.16,
#   'duration': 4.72},
#  {'text': 'remember my first ai program being uh',
#   'start': 776.16,
#   'duration': 5.119},
#  {'text': "programming my amiga it couldn't it",
#   'start': 778.88,
#   'duration': 4.0},
#  {'text': "wasn't powerful enough to play chess i",
#   'start': 781.279,
#   'duration': 2.961},
#  {'text': "couldn't write a whole chess program but",
#   'start': 782.88,
#   'duration': 3.84},
#  {'text': 'i wrote a program for it to play othello',
#   'start': 784.24,
#   'duration': 4.0},
#  {'text': "reversey it's sometimes called i think",
#   'start': 786.72,
#   'duration': 3.919},
#  {'text': 'in the u.s and so a slightly simpler',
#   'start': 788.24,
#   'duration': 4.32},
#  {'text': 'game than chess but i used all of the',
#   'start': 790.639,
#   'duration': 3.841},
#  {'text': 'principles that chess programs had alpha',
#   'start': 792.56,
#   'duration': 3.92},
#  {'text': 'beta search all of that and that was my',
#   'start': 794.48,
#   'duration': 3.28},
#  {'text': 'first ai program i remember that very',
#   'start': 796.48,
#   'duration': 3.2},
#  {'text': 'well was around 12 years old so that',
#   'start': 797.76,
#   'duration': 4.079},
#  {'text': 'that that brought me into ai and then',
#   'start': 799.68,
#   'duration': 4.56},
#  {'text': 'the second part was later on uh when i',
#   'start': 801.839,
#   'duration': 4.721},
#  {'text': 'was around 1617 and i was writing games',
#   'start': 804.24,
#   'duration': 4.48},
#  {'text': 'professionally designing games uh',
#   'start': 806.56,
#   'duration': 4.32},
#  {'text': 'writing a game called theme park which',
#   'start': 808.72,
#   'duration': 5.2},
#  {'text': 'um had ai as a core gameplay component',
#   'start': 810.88,
#   'duration': 5.92},
#  {'text': 'as part of the simulation um and it sold',
#   'start': 813.92,
#   'duration': 4.159},
#  {'text': 'you know millions of copies around the',
#   'start': 816.8,
#   'duration': 3.44},
#  {'text': 'world and people loved the way that the',
#   'start': 818.079,
#   'duration': 4.081},
#  {'text': 'ai even though it was relatively simple',
#   'start': 820.24,
#   'duration': 4.8},
#  {'text': "by today's ai standards um was was",
#   'start': 822.16,
#   'duration': 4.479},
#  {'text': 'reacting to the way you as the player',
#   'start': 825.04,
#   'duration': 3.76},
#  {'text': 'played it so it was called a sandbox',
#   'start': 826.639,
#   'duration': 3.921},
#  {'text': "game so it's one of the first types of",
#   'start': 828.8,
#   'duration': 4.159},
#  {'text': 'games like that along with simcity and',
#   'start': 830.56,
#   'duration': 4.0},
#  {'text': 'it meant that every game you played was',
#   'start': 832.959,
#   'duration': 2.641},
#  {'text': 'unique', 'start': 834.56, 'duration': 2.8},
#  {'text': 'is there something you could say just on',
#   'start': 835.6,
#   'duration': 3.2},
#  {'text': 'a small tangent', 'start': 837.36, 'duration': 2.4},
#  {'text': 'about', 'start': 838.8, 'duration': 5.36},
#  {'text': 'really impressive ai from a game design',
#   'start': 839.76,
#   'duration': 6.8},
#  {'text': 'human enjoyment perspective', 'start': 844.16, 'duration': 4.72},
#  {'text': "really impressive ai that you've seen in",
#   'start': 846.56,
#   'duration': 4.48},
#  {'text': 'games and maybe what does it take to',
#   'start': 848.88,
#   'duration': 4.319},
#  {'text': 'create ai system and how hard of a',
#   'start': 851.04,
#   'duration': 5.039},
#  {'text': 'problem is that so a million questions',
#   'start': 853.199,
#   'duration': 5.041},
#  {'text': 'just as a brief tangent', 'start': 856.079, 'duration': 4.161},
#  {'text': 'well look i think um', 'start': 858.24, 'duration': 4.32},
#  {'text': 'games uh games have been significant in',
#   'start': 860.24,
#   'duration': 3.92},
#  {'text': 'my life for three reasons so first of',
#   'start': 862.56,
#   'duration': 3.519},
#  {'text': 'all to to i was playing them and',
#   'start': 864.16,
#   'duration': 3.919},
#  {'text': 'training myself on games when i was a',
#   'start': 866.079,
#   'duration': 4.241},
#  {'text': 'kid then i went through a phase of',
#   'start': 868.079,
#   'duration': 4.88},
#  {'text': 'designing games and writing ai4 games so',
#   'start': 870.32,
#   'duration': 4.959},
#  {'text': 'all the games i i professionally wrote',
#   'start': 872.959,
#   'duration': 4.801},
#  {'text': 'uh had ai as a core component and that',
#   'start': 875.279,
#   'duration': 5.521},
#  {'text': 'was mostly in the in the 90s and the',
#   'start': 877.76,
#   'duration': 4.639},
#  {'text': 'reason i was doing that in games',
#   'start': 880.8,
#   'duration': 3.599},
#  {'text': 'industry was at the time the games',
#   'start': 882.399,
#   'duration': 3.761},
#  {'text': 'industry i think was the cutting edge of',
#   'start': 884.399,
#   'duration': 4.0},
#  {'text': 'technology so whether it was graphics',
#   'start': 886.16,
#   'duration': 4.16},
#  {'text': 'with people like john carmack and quake',
#   'start': 888.399,
#   'duration': 5.281},
#  {'text': 'and those kind of things or ai i think',
#   'start': 890.32,
#   'duration': 5.04},
#  {'text': 'actually all the action was going on in',
#   'start': 893.68,
#   'duration': 3.599},
#  {'text': "games and and we've seen we're still",
#   'start': 895.36,
#   'duration': 3.36},
#  {'text': 'reaping the benefits of that even with',
#   'start': 897.279,
#   'duration': 3.68},
#  {'text': 'things like gpus which you know i find',
#   'start': 898.72,
#   'duration': 3.6},
#  {'text': 'ironic was obviously invented for',
#   'start': 900.959,
#   'duration': 2.961},
#  {'text': 'graphics computer graphics but then',
#   'start': 902.32,
#   'duration': 3.759},
#  {'text': 'turns out to be amazingly useful for ai',
#   'start': 903.92,
#   'duration': 3.68},
#  {'text': "it just turns out everything's a matrix",
#   'start': 906.079,
#   'duration': 3.76},
#  {'text': 'multiplication it appears you know in',
#   'start': 907.6,
#   'duration': 3.44},
#  {'text': 'the whole world', 'start': 909.839, 'duration': 4.24},
#  {'text': 'so um so i think games at the time had',
#   'start': 911.04,
#   'duration': 5.12},
#  {'text': 'the most cutting edge ai and a lot of',
#   'start': 914.079,
#   'duration': 4.721},
#  {'text': 'the the games uh uh we you know i was',
#   'start': 916.16,
#   'duration': 4.08},
#  {'text': 'involved in writing so there was a game',
#   'start': 918.8,
#   'duration': 2.8},
#  {'text': 'called black and white which was one',
#   'start': 920.24,
#   'duration': 2.8},
#  {'text': 'game i was involved with in the early',
#   'start': 921.6,
#   'duration': 3.919},
#  {'text': 'stages of which i still think is the',
#   'start': 923.04,
#   'duration': 3.76},
#  {'text': 'most um', 'start': 925.519, 'duration': 3.44},
#  {'text': 'impressive uh example of reinforcement',
#   'start': 926.8,
#   'duration': 4.24},
#  {'text': 'learning in a computer game so in that',
#   'start': 928.959,
#   'duration': 3.921},
#  {'text': 'game you know you trained a little pet',
#   'start': 931.04,
#   'duration': 4.159},
#  {'text': 'animal uh and', 'start': 932.88, 'duration': 4.0},
#  {'text': 'yeah and it sort of learned from how you',
#   'start': 935.199,
#   'duration': 3.2},
#  {'text': 'were treating it so if you treated it',
#   'start': 936.88,
#   'duration': 4.0},
#  {'text': 'badly then it became mean yeah and then',
#   'start': 938.399,
#   'duration': 4.401},
#  {'text': 'it would be mean to to your villagers',
#   'start': 940.88,
#   'duration': 3.6},
#  {'text': 'and your and your population the sort of',
#   'start': 942.8,
#   'duration': 3.2},
#  {'text': 'uh the little tribe that you were',
#   'start': 944.48,
#   'duration': 3.52},
#  {'text': 'running uh but if you were kind to it',
#   'start': 946.0,
#   'duration': 3.68},
#  {'text': 'then it would be kind and people were',
#   'start': 948.0,
#   'duration': 3.759},
#  {'text': 'fascinated by how that was and so was i',
#   'start': 949.68,
#   'duration': 3.519},
#  {'text': 'to be honest with the way it kind of',
#   'start': 951.759,
#   'duration': 4.08},
#  {'text': 'developed and um especially the mapping',
#   'start': 953.199,
#   'duration': 4.961},
#  {'text': 'to good and evil yeah it made you made',
#   'start': 955.839,
#   'duration': 5.281},
#  {'text': 'you realize made me realize that you can',
#   'start': 958.16,
#   'duration': 4.96},
#  {'text': 'sort of in the way in the choices you',
#   'start': 961.12,
#   'duration': 4.0},
#  {'text': 'make can define', 'start': 963.12, 'duration': 3.04},
#  {'text': 'uh the', 'start': 965.12, 'duration': 4.079},
#  {'text': 'where you end up and that means',
#   'start': 966.16,
#   'duration': 5.52},
#  {'text': 'all of us are capable of the good',
#   'start': 969.199,
#   'duration': 5.281},
#  {'text': 'uh evil it all matters in uh the',
#   'start': 971.68,
#   'duration': 4.719},
#  {'text': 'different choices along the trajectory',
#   'start': 974.48,
#   'duration': 3.76},
#  {'text': "to those places that you make it's",
#   'start': 976.399,
#   'duration': 3.921},
#  {'text': 'fascinating i mean games can do that',
#   'start': 978.24,
#   'duration': 3.68},
#  {'text': "philosophically to you and it's rare it",
#   'start': 980.32,
#   'duration': 3.519},
#  {'text': 'seems rare yeah well games are i think a',
#   'start': 981.92,
#   'duration': 4.24},
#  {'text': 'unique medium because um you as the',
#   'start': 983.839,
#   'duration': 3.601},
#  {'text': "player you're not just passively",
#   'start': 986.16,
#   'duration': 4.08},
#  {'text': 'consuming the the entertainment right',
#   'start': 987.44,
#   'duration': 5.28},
#  {'text': "you're actually actively involved as an",
#   'start': 990.24,
#   'duration': 4.88},
#  {'text': "as a as an agent so i think that's what",
#   'start': 992.72,
#   'duration': 3.84},
#  {'text': 'makes it in some ways can be more',
#   'start': 995.12,
#   'duration': 3.36},
#  {'text': 'visceral than other other mediums like',
#   'start': 996.56,
#   'duration': 3.839},
#  {'text': 'you know films and books so the second',
#   'start': 998.48,
#   'duration': 3.68},
#  {'text': 'so that was you know designing ai and',
#   'start': 1000.399,
#   'duration': 4.961},
#  {'text': "games and then the third use uh uh i've",
#   'start': 1002.16,
#   'duration': 5.44},
#  {'text': "we've used of ai is in deep mind from",
#   'start': 1005.36,
#   'duration': 4.399},
#  {'text': 'the beginning which is using games as a',
#   'start': 1007.6,
#   'duration': 5.12},
#  {'text': 'testing ground for proving out ai',
#   'start': 1009.759,
#   'duration': 5.121},
#  {'text': 'algorithms and developing ai algorithms',
#   'start': 1012.72,
#   'duration': 4.88},
#  {'text': 'and that was a that was a sort of um a',
#   'start': 1014.88,
#   'duration': 4.319},
#  {'text': 'core component of our vision at the',
#   'start': 1017.6,
#   'duration': 3.44},
#  {'text': 'start of deepmind was that we would use',
#   'start': 1019.199,
#   'duration': 4.721},
#  {'text': 'games very heavily uh as our main',
#   'start': 1021.04,
#   'duration': 4.879},
#  {'text': 'testing ground certainly to begin with',
#   'start': 1023.92,
#   'duration': 3.84},
#  {'text': "um because it's super efficient to use",
#   'start': 1025.919,
#   'duration': 4.321},
#  {'text': "games and also you know it's very easy",
#   'start': 1027.76,
#   'duration': 5.039},
#  {'text': 'to have metrics to see how well your',
#   'start': 1030.24,
#   'duration': 4.559},
#  {'text': 'systems are improving and what direction',
#   'start': 1032.799,
#   'duration': 3.28},
#  {'text': 'your ideas are going in and whether',
#   'start': 1034.799,
#   'duration': 3.441},
#  {'text': "you're making incremental improvements",
#   'start': 1036.079,
#   'duration': 4.24},
#  {'text': 'and because those games are often rooted',
#   'start': 1038.24,
#   'duration': 3.679},
#  {'text': 'in something that humans did for a long',
#   'start': 1040.319,
#   'duration': 2.961},
#  {'text': 'time beforehand', 'start': 1041.919, 'duration': 3.76},
#  {'text': "there's already a strong", 'start': 1043.28, 'duration': 4.0},
#  {'text': "set of rules like it's already a damn",
#   'start': 1045.679,
#   'duration': 3.681},
#  {'text': "good benchmark yes it's really good for",
#   'start': 1047.28,
#   'duration': 3.92},
#  {'text': "so many reasons because you've got",
#   'start': 1049.36,
#   'duration': 3.52},
#  {'text': "you've got you've got clear measures of",
#   'start': 1051.2,
#   'duration': 4.24},
#  {'text': 'how good humans can be at these things',
#   'start': 1052.88,
#   'duration': 4.159},
#  {'text': "and in some cases like go we've been",
#   'start': 1055.44,
#   'duration': 4.479},
#  {'text': 'playing it for thousands of years um and',
#   'start': 1057.039,
#   'duration': 4.961},
#  {'text': 'and uh often they have scores or at',
#   'start': 1059.919,
#   'duration': 4.401},
#  {'text': "least win conditions so it's very easy",
#   'start': 1062.0,
#   'duration': 3.919},
#  {'text': 'for reward learning systems to get a',
#   'start': 1064.32,
#   'duration': 3.12},
#  {'text': "reward it's very easy to specify what",
#   'start': 1065.919,
#   'duration': 4.64},
#  {'text': 'that reward is um and uh also at the end',
#   'start': 1067.44,
#   'duration': 5.359},
#  {'text': "it's easy to you know to test uh",
#   'start': 1070.559,
#   'duration': 3.921},
#  {'text': 'externally you know', 'start': 1072.799, 'duration': 4.0},
#  {'text': 'how strong is your system by of course',
#   'start': 1074.48,
#   'duration': 3.84},
#  {'text': "playing against you know the world's",
#   'start': 1076.799,
#   'duration': 4.24},
#  {'text': "strongest players at those games so it's",
#   'start': 1078.32,
#   'duration': 4.32},
#  {'text': "it's so good for so many reasons and",
#   'start': 1081.039,
#   'duration': 3.441},
#  {'text': "it's also very efficient to run",
#   'start': 1082.64,
#   'duration': 4.08},
#  {'text': 'potentially millions of simulations in',
#   'start': 1084.48,
#   'duration': 5.12},
#  {'text': 'parallel on the cloud so um i think',
#   'start': 1086.72,
#   'duration': 4.88},
#  {'text': "there's a huge reason why we were so",
#   'start': 1089.6,
#   'duration': 4.24},
#  {'text': 'successful back in you know starting out',
#   'start': 1091.6,
#   'duration': 4.319},
#  {'text': '2010 how come we were able to progress',
#   'start': 1093.84,
#   'duration': 4.959},
#  {'text': "so quickly because we'd utilize games",
#   'start': 1095.919,
#   'duration': 5.041},
#  {'text': 'and um you know at the beginning of deep',
#   'start': 1098.799,
#   'duration': 4.481},
#  {'text': 'mind we also hired some amazing game',
#   'start': 1100.96,
#   'duration': 4.88},
#  {'text': 'engineers uh who i knew from my previous',
#   'start': 1103.28,
#   'duration': 5.44},
#  {'text': 'uh lives in the games industry and uh',
#   'start': 1105.84,
#   'duration': 4.4},
#  {'text': 'and that helped to bootstrap us very',
#   'start': 1108.72,
#   'duration': 4.0},
#  {'text': "quickly and plus it's somehow super",
#   'start': 1110.24,
#   'duration': 4.72},
#  {'text': 'compelling almost at a philosophical',
#   'start': 1112.72,
#   'duration': 5.52},
#  {'text': 'level of man versus machine', 'start': 1114.96, 'duration': 6.079},
#  {'text': 'over over a chessboard or a go board',
#   'start': 1118.24,
#   'duration': 4.559},
#  {'text': 'and especially given that the entire',
#   'start': 1121.039,
#   'duration': 3.441},
#  {'text': 'history of ai is defined by people',
#   'start': 1122.799,
#   'duration': 3.76},
#  {'text': "saying it's going to be impossible to",
#   'start': 1124.48,
#   'duration': 4.0},
#  {'text': 'make a machine that', 'start': 1126.559, 'duration': 4.321},
#  {'text': 'beats a human being in chess', 'start': 1128.48, 'duration': 4.559},
#  {'text': 'and then once that happened', 'start': 1130.88, 'duration': 4.4},
#  {'text': 'people were certain when i was coming up',
#   'start': 1133.039,
#   'duration': 4.161},
#  {'text': 'in ai that go', 'start': 1135.28, 'duration': 3.36},
#  {'text': 'is not a game that could be solved',
#   'start': 1137.2,
#   'duration': 3.92},
#  {'text': 'because of the combinatorial complexity',
#   'start': 1138.64,
#   'duration': 5.52},
#  {'text': "it's just too it's it's it's you know",
#   'start': 1141.12,
#   'duration': 5.439},
#  {'text': "no matter how much moore's law you have",
#   'start': 1144.16,
#   'duration': 4.32},
#  {'text': 'compute is just never going to be able',
#   'start': 1146.559,
#   'duration': 4.721},
# ...
#   'duration': 3.76},
#  {'text': 'enough to you know you might be able to',
#   'start': 1736.64,
#   'duration': 2.8},
#  {'text': 'do that like overnight', 'start': 1737.919, 'duration': 4.721},
#  {'text': 'do you think a game that is optimal',
#   'start': 1739.44,
#   'duration': 5.44},
#  {'text': 'designed by an ai system', 'start': 1742.64, 'duration': 5.039},
#  {'text': 'would look very much like uh planet',
#   'start': 1744.88,
#   'duration': 4.72},
#  {'text': 'earth', 'start': 1747.679, 'duration': 3.921},
#  {'text': "maybe maybe it's only the sort of game i",
#   'start': 1749.6,
#   'duration': 4.319},
#  {'text': "would love to make is is and i've tried",
#   'start': 1751.6,
#   'duration': 4.4},
#  {'text': "you know my in my game's career the",
#   'start': 1753.919,
#   'duration': 4.081},
#  {'text': 'games design career you know my first',
#   'start': 1756.0,
#   'duration': 4.24},
#  {'text': 'big game was designing a theme park an',
#   'start': 1758.0,
#   'duration': 5.039},
#  {'text': 'amusement park then uh with games like',
#   'start': 1760.24,
#   'duration': 4.799},
#  {'text': 'republic i tried to you know have games',
#   'start': 1763.039,
#   'duration': 4.081},
#  {'text': 'where we designed whole cities and and',
#   'start': 1765.039,
#   'duration': 4.321},
#  {'text': 'allowed you to play in so and of course',
#   'start': 1767.12,
#   'duration': 3.76},
#  {'text': 'people like will wright have written',
#   'start': 1769.36,
#   'duration': 3.52},
#  {'text': 'games like sim earth uh trying to',
#   'start': 1770.88,
#   'duration': 3.519},
#  {'text': 'simulate the whole of earth pretty',
#   'start': 1772.88,
#   'duration': 3.84},
#  {'text': "tricky but um i see earth i haven't",
#   'start': 1774.399,
#   'duration': 3.921},
#  {'text': 'actually played that one so what is it',
#   'start': 1776.72,
#   'duration': 3.76},
#  {'text': 'does it incorporative evolution or yeah',
#   'start': 1778.32,
#   'duration': 4.4},
#  {'text': "it has evolution and it's sort of um it",
#   'start': 1780.48,
#   'duration': 3.84},
#  {'text': 'tries to it sort of treats it as an',
#   'start': 1782.72,
#   'duration': 3.28},
#  {'text': 'entire biosphere but from quite a high',
#   'start': 1784.32,
#   'duration': 2.88},
#  {'text': 'level', 'start': 1786.0, 'duration': 2.159},
#  {'text': 'so', 'start': 1787.2, 'duration': 3.199},
#  {'text': 'nice to be able to sort of zoom in zoom',
#   'start': 1788.159,
#   'duration': 4.081},
#  {'text': 'out zoom in exactly so obviously he',
#   'start': 1790.399,
#   'duration': 3.041},
#  {'text': "couldn't do that was in the night i",
#   'start': 1792.24,
#   'duration': 2.799},
#  {'text': 'think he wrote that in the 90s so it',
#   'start': 1793.44,
#   'duration': 2.959},
#  {'text': "couldn't you know it wasn't it wasn't",
#   'start': 1795.039,
#   'duration': 3.36},
#  {'text': 'able to do that but that that would be',
#   'start': 1796.399,
#   'duration': 4.081},
#  {'text': 'uh obviously the ultimate sandbox game',
#   'start': 1798.399,
#   'duration': 2.961},
#  {'text': 'of course', 'start': 1800.48, 'duration': 2.4},
#  {'text': "on that topic do you think we're living",
#   'start': 1801.36,
#   'duration': 3.36},
#  {'text': 'in a simulation', 'start': 1802.88, 'duration': 4.08},
#  {'text': "yes well so okay so i'm gonna jump",
#   'start': 1804.72,
#   'duration': 4.48},
#  {'text': 'around from the absurdly philosophical',
#   'start': 1806.96,
#   'duration': 4.64},
#  {'text': 'to the short term sure very very happy',
#   'start': 1809.2,
#   'duration': 4.24},
#  {'text': 'to so i think uh my answer to that',
#   'start': 1811.6,
#   'duration': 4.16},
#  {'text': 'question is a little bit complex because',
#   'start': 1813.44,
#   'duration': 4.32},
#  {'text': 'uh there is simulation theory which',
#   'start': 1815.76,
#   'duration': 3.68},
#  {'text': 'obviously nick bostrom i think famously',
#   'start': 1817.76,
#   'duration': 3.84},
#  {'text': 'first proposed um', 'start': 1819.44, 'duration': 4.64},
#  {'text': "and uh i don't quite believe it in in",
#   'start': 1821.6,
#   'duration': 5.28},
#  {'text': 'that sense so um in the in the sense',
#   'start': 1824.08,
#   'duration': 4.8},
#  {'text': 'that uh are we in some sort of computer',
#   'start': 1826.88,
#   'duration': 4.799},
#  {'text': 'game or have our descendants somehow',
#   'start': 1828.88,
#   'duration': 5.6},
#  {'text': 'recreated uh uh earth in the you know',
#   'start': 1831.679,
#   'duration': 5.281},
#  {'text': '21st century and and some for some kind',
#   'start': 1834.48,
#   'duration': 5.28},
#  {'text': 'of experimental reason i think that um',
#   'start': 1836.96,
#   'duration': 5.68},
#  {'text': 'but i do think that we that that we',
#   'start': 1839.76,
#   'duration': 4.799},
#  {'text': 'might be that the best way to understand',
#   'start': 1842.64,
#   'duration': 4.88},
#  {'text': 'physics and the universe is from a',
#   'start': 1844.559,
#   'duration': 5.041},
#  {'text': 'computational perspective so', 'start': 1847.52, 'duration': 3.84},
#  {'text': 'understanding it as an information',
#   'start': 1849.6,
#   'duration': 4.4},
#  {'text': 'universe and actually information being',
#   'start': 1851.36,
#   'duration': 6.88},
#  {'text': 'the most fundamental unit of uh reality',
#   'start': 1854.0,
#   'duration': 6.0},
#  {'text': 'rather than matter or energy so a',
#   'start': 1858.24,
#   'duration': 3.6},
#  {'text': 'physicist would say you know matter or',
#   'start': 1860.0,
#   'duration': 3.6},
#  {'text': 'energy you know e equals m c squared',
#   'start': 1861.84,
#   'duration': 3.76},
#  {'text': 'these are the things that are are the',
#   'start': 1863.6,
#   'duration': 3.919},
#  {'text': "fundamentals of the universe i'd",
#   'start': 1865.6,
#   'duration': 4.4},
#  {'text': 'actually say information um which of',
#   'start': 1867.519,
#   'duration': 5.201},
#  {'text': 'course itself can be can specify energy',
#   'start': 1870.0,
#   'duration': 4.559},
#  {'text': 'or matter right matter is actually just',
#   'start': 1872.72,
#   'duration': 3.52},
#  {'text': "you know we're we're just out the way",
#   'start': 1874.559,
#   'duration': 3.441},
#  {'text': 'our bodies and all the molecules in our',
#   'start': 1876.24,
#   'duration': 4.08},
#  {'text': 'body arrange is information so i think',
#   'start': 1878.0,
#   'duration': 4.799},
#  {'text': 'information may be the most fundamental',
#   'start': 1880.32,
#   'duration': 4.64},
#  {'text': 'way to describe the universe and',
#   'start': 1882.799,
#   'duration': 4.401},
#  {'text': "therefore you could say we're in some",
#   'start': 1884.96,
#   'duration': 4.719},
#  {'text': 'sort of simulation because of that um',
#   'start': 1887.2,
#   'duration': 4.16},
#  {'text': "but i don't i do i'm not i'm not really",
#   'start': 1889.679,
#   'duration': 4.24},
#  {'text': 'a subscriber to the idea that um you',
#   'start': 1891.36,
#   'duration': 4.08},
#  {'text': 'know these are sort of throw away',
#   'start': 1893.919,
#   'duration': 3.12},
#  {'text': 'billions of simulations around i think',
#   'start': 1895.44,
#   'duration': 4.16},
#  {'text': 'this is actually very critical and',
#   'start': 1897.039,
#   'duration': 4.88},
#  {'text': 'possibly unique this simulation',
#   'start': 1899.6,
#   'duration': 4.319},
#  {'text': 'particular one yes so but and you just',
#   'start': 1901.919,
#   'duration': 3.281},
#  {'text': 'mean', 'start': 1903.919, 'duration': 3.041},
#  {'text': 'treating the universe', 'start': 1905.2, 'duration': 3.52},
#  {'text': 'as a computer', 'start': 1906.96, 'duration': 2.719},
#  {'text': "that's", 'start': 1908.72, 'duration': 3.439},
#  {'text': 'processing and modifying information',
#   'start': 1909.679,
#   'duration': 4.161},
#  {'text': 'is is a good way to solve the problems',
#   'start': 1912.159,
#   'duration': 5.041},
#  {'text': 'of physics of chemistry of biology',
#   'start': 1913.84,
#   'duration': 6.24},
#  {'text': 'and perhaps of humanity and so on yes i',
#   'start': 1917.2,
#   'duration': 5.68},
#  {'text': 'think understanding physics in terms of',
#   'start': 1920.08,
#   'duration': 5.52},
#  {'text': 'information theory uh might be the best',
#   'start': 1922.88,
#   'duration': 5.12},
#  {'text': "way to to really uh understand what's",
#   'start': 1925.6,
#   'duration': 3.679},
#  {'text': 'going on here', 'start': 1928.0, 'duration': 4.32},
#  {'text': 'from our understanding of a universal',
#   'start': 1929.279,
#   'duration': 5.361},
#  {'text': 'turing machine from our understanding of',
#   'start': 1932.32,
#   'duration': 3.44},
#  {'text': "a computer do you think there's",
#   'start': 1934.64,
#   'duration': 3.68},
#  {'text': 'something outside of the capabilities of',
#   'start': 1935.76,
#   'duration': 4.639},
#  {'text': 'a computer that is present in our',
#   'start': 1938.32,
#   'duration': 4.239},
#  {'text': 'universe you have a disagreement with',
#   'start': 1940.399,
#   'duration': 3.681},
#  {'text': 'roger penrose', 'start': 1942.559, 'duration': 3.761},
#  {'text': 'the nature of consciousness he he thinks',
#   'start': 1944.08,
#   'duration': 3.92},
#  {'text': 'that consciousness is more than just a',
#   'start': 1946.32,
#   'duration': 3.28},
#  {'text': 'computation', 'start': 1948.0, 'duration': 3.6},
#  {'text': 'uh do you think all of it the whole',
#   'start': 1949.6,
#   'duration': 4.319},
#  {'text': 'shebang is can be can be a competition',
#   'start': 1951.6,
#   'duration': 4.079},
#  {'text': "yeah i've had many fascinating debates",
#   'start': 1953.919,
#   'duration': 4.161},
#  {'text': 'with uh sir roger penrose and obviously',
#   'start': 1955.679,
#   'duration': 4.641},
#  {'text': "he's he's famously and i read you know",
#   'start': 1958.08,
#   'duration': 4.64},
#  {'text': 'emperors of new mind and and um',
#   'start': 1960.32,
#   'duration': 4.8},
#  {'text': 'and his books uh his classical books uh',
#   'start': 1962.72,
#   'duration': 3.839},
#  {'text': 'and they they were pretty influential',
#   'start': 1965.12,
#   'duration': 3.76},
#  {'text': 'and you know in the 90s and um he',
#   'start': 1966.559,
#   'duration': 4.0},
#  {'text': "believes that there's something more you",
#   'start': 1968.88,
#   'duration': 4.159},
#  {'text': 'know something quantum that is needed to',
#   'start': 1970.559,
#   'duration': 5.36},
#  {'text': 'explain consciousness in the brain um i',
#   'start': 1973.039,
#   'duration': 4.64},
#  {'text': "think about what we're doing actually at",
#   'start': 1975.919,
#   'duration': 3.76},
#  {'text': 'deepmind and what my career is being',
#   'start': 1977.679,
#   'duration': 4.24},
#  {'text': "we're almost like true rings champion so",
#   'start': 1979.679,
#   'duration': 3.921},
#  {'text': 'we are pushing turing machines or',
#   'start': 1981.919,
#   'duration': 4.161},
#  {'text': 'classical computation to the limits what',
#   'start': 1983.6,
#   'duration': 4.4},
#  {'text': 'are the limits of what classical',
#   'start': 1986.08,
#   'duration': 4.959},
#  {'text': 'computing can do now um and at the same',
#   'start': 1988.0,
#   'duration': 5.679},
#  {'text': "time i've also studied neuroscience to",
#   'start': 1991.039,
#   'duration': 4.48},
#  {'text': "see and that's why i did my phd in was",
#   'start': 1993.679,
#   'duration': 4.161},
#  {'text': 'to see also to look at you know is there',
#   'start': 1995.519,
#   'duration': 3.76},
#  {'text': 'anything quantum in the brain from a',
#   'start': 1997.84,
#   'duration': 3.28},
#  {'text': 'neuroscience or biological perspective',
#   'start': 1999.279,
#   'duration': 4.321},
#  {'text': 'and um and so far i think most',
#   'start': 2001.12,
#   'duration': 3.919},
#  {'text': 'neuroscientists and most mainstream',
#   'start': 2003.6,
#   'duration': 2.959},
#  {'text': 'biologists and neuroscientists would say',
#   'start': 2005.039,
#   'duration': 3.76},
#  {'text': "there's no evidence of any quantum uh",
#   'start': 2006.559,
#   'duration': 4.321},
#  {'text': 'systems or effects in the brain as far',
#   'start': 2008.799,
#   'duration': 3.681},
#  {'text': "as we can see it's it can be mostly",
#   'start': 2010.88,
#   'duration': 4.08},
#  {'text': 'explained by classical uh classical',
#   'start': 2012.48,
#   'duration': 4.559},
#  {'text': 'theories so', 'start': 2014.96, 'duration': 3.92},
#  {'text': "and then so there's sort of the the",
#   'start': 2017.039,
#   'duration': 4.081},
#  {'text': 'search from the biology side and then at',
#   'start': 2018.88,
#   'duration': 4.32},
#  {'text': "the same time there's the raising of the",
#   'start': 2021.12,
#   'duration': 4.799},
#  {'text': 'water uh at the bar from what classical',
#   'start': 2023.2,
#   'duration': 5.68},
#  {'text': 'turing machines can do uh uh and',
#   'start': 2025.919,
#   'duration': 4.801},
#  {'text': 'and you know including our new ai',
#   'start': 2028.88,
#   'duration': 5.12},
#  {'text': 'systems and uh as you alluded to earlier',
#   'start': 2030.72,
#   'duration': 5.679},
#  {'text': 'um you know i think ai especially in the',
#   'start': 2034.0,
#   'duration': 5.12},
#  {'text': 'last decade plus has been a continual',
#   'start': 2036.399,
#   'duration': 5.921},
#  {'text': 'story now of surprising uh events uh and',
#   'start': 2039.12,
#   'duration': 5.6},
#  {'text': 'surprising successes knocking over one',
#   'start': 2042.32,
#   'duration': 4.079},
#  {'text': 'theory after another of what was thought',
#   'start': 2044.72,
#   'duration': 3.76},
#  {'text': 'to be impossible you know from go to',
#   'start': 2046.399,
#   'duration': 5.121},
#  {'text': 'protein folding and so on and so i think',
#   'start': 2048.48,
#   'duration': 4.0},
#  {'text': 'um', 'start': 2051.52, 'duration': 4.559},
#  {'text': 'i would be very hesitant to bet against',
#   'start': 2052.48,
#   'duration': 6.96},
#  {'text': 'how far the uh universal turing machine',
#   'start': 2056.079,
#   'duration': 6.56},
#  {'text': 'and classical computation paradigm can',
#   'start': 2059.44,
#   'duration': 5.84},
#  {'text': 'go and and my betting would be',
#   'start': 2062.639,
#   'duration': 5.121},
#  {'text': "that all of certainly what's going on in",
#   'start': 2065.28,
#   'duration': 5.599},
#  {'text': 'our brain uh can probably be mimicked or',
#   'start': 2067.76,
#   'duration': 5.599},
#  {'text': 'or approximated on a on a classical',
#   'start': 2070.879,
#   'duration': 5.04},
#  {'text': 'machine um not you know not requiring',
#   'start': 2073.359,
#   'duration': 5.121},
#  {'text': 'something metaphysical or quantum and',
#   'start': 2075.919,
#   'duration': 4.321},
#  {'text': "we'll get there with some of the work",
#   'start': 2078.48,
#   'duration': 3.199},
#  {'text': 'with alpha fold', 'start': 2080.24, 'duration': 4.159},
#  {'text': 'which i think begins the journey of',
#   'start': 2081.679,
#   'duration': 4.72},
#  {'text': 'modeling this beautiful and complex',
#   'start': 2084.399,
#   'duration': 4.401},
#  {'text': 'world of biology so you think all the',
#   'start': 2086.399,
#   'duration': 4.881},
#  {'text': 'magic of the human mind comes from this',
#   'start': 2088.8,
#   'duration': 5.359},
#  {'text': 'just a few pounds of mush', 'start': 2091.28, 'duration': 6.079},
#  {'text': 'of a biological computational mush',
#   'start': 2094.159,
#   'duration': 4.081},
#  {'text': "that's", 'start': 2097.359, 'duration': 4.081},
#  {'text': 'akin to some of the neural networks',
#   'start': 2098.24,
#   'duration': 6.24},
#  {'text': 'not directly but in spirit that deep',
#   'start': 2101.44,
#   'duration': 5.12},
#  {'text': 'mind has been working with well look i',
#   'start': 2104.48,
#   'duration': 3.84},
#  {'text': "think it's um you say it's a few you",
#   'start': 2106.56,
#   'duration': 3.36},
#  {'text': "know of course it's this is the i think",
#   'start': 2108.32,
#   'duration': 3.279},
#  {'text': 'the biggest miracle of the universe is',
#   'start': 2109.92,
#   'duration': 4.159},
#  {'text': 'that um it is just a few pounds of mush',
#   'start': 2111.599,
#   'duration': 4.641},
#  {'text': "in our skulls and yet it's also our",
#   'start': 2114.079,
#   'duration': 4.0},
#  {'text': 'brains are the most complex objects in',
#   'start': 2116.24,
#   'duration': 3.92},
#  {'text': 'the in that we know of in the universe',
#   'start': 2118.079,
#   'duration': 3.601},
#  {'text': "so there's something profoundly",
#   'start': 2120.16,
#   'duration': 3.679},
#  {'text': 'beautiful and amazing about our brains',
#   'start': 2121.68,
#   'duration': 2.96},
#  ...]

# %% [markdown]
# Step 1 (b) - Indexing (Text Splitting)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 168

# %%
chunks[100]
# Out:
# Document(metadata={}, page_content="and and kind of come up with descriptions of the electron clouds where they're gonna go how they're gonna interact when you put two elements together uh and what we try to do is learn a simulation uh uh learner functional that will describe more chemistry types of chemistry so um until now you know you can run expensive simulations but then you can only simulate very small uh molecules very simple molecules we would like to simulate large materials um and so uh today there's no way of doing that and we're building up towards uh building functionals that approximate schrodinger's equation and then allow you to describe uh what the electrons are doing and all materials sort of science and material properties are governed by the electrons and and how they interact so have a good summarization of the simulation through the functional um but one that is still close to what the actual simulation would come out with so what um how difficult is that to ask what's involved in that task is it")

# %% [markdown]
# Step 1 (c&d) - Indexing (Embedding Generation and Storing in Vector Store)

# %%
# HF_Embeddding Used
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Step : Create the FAISS vector store from documents
vector_store = FAISS.from_documents(
    documents = chunks,
    embedding = embedding_model
)
# Out:
# /tmp/ipython-input-10-932193092.py:2: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '190a8760-5bba-421a-9ad4-3a47002db43d',
#  1: '331d20c7-ff81-47b1-ad68-4dfe1ae19377',
#  2: '2d8923be-cbca-4863-a412-feef111b8af8',
#  3: '331df55f-75b3-4255-b0c3-a14aee9266d9',
#  4: '7bd6596a-e0ff-4497-aeea-446165c80a57',
#  5: 'bb88952e-68ff-4b30-89ca-dcdd568629ca',
#  6: '013cd45d-248b-4fec-939f-dc997c2e8781',
#  7: '1443befe-5f1d-4fb1-8ebb-eead77ec5339',
#  8: '2c44dfc3-e401-4006-859f-c18a0ae87560',
#  9: '0bef435a-3ca3-4f2f-9ca6-d8a288b117d4',
#  10: '53a92a5a-bfdc-4ad0-9220-9ec6e88fe3d5',
#  11: '960d7a73-e592-4613-84b5-9e8feaf83334',
#  12: '7b5a86ea-cafe-44de-bc15-bfed5788f911',
#  13: '592ce92c-5805-4b81-86e2-f9495abb65be',
#  14: '6d6c28d4-ec65-4766-9582-85d5dfc676ce',
#  15: '5b610996-a993-4a9a-bb52-c4867af66fbf',
#  16: '08d252a4-f670-4ebc-8b81-df304491c745',
#  17: '98971bd1-9285-413b-9f19-a7e38f7db821',
#  18: '8f4b1c20-73b7-41de-b56b-840e75177344',
#  19: '4683bc12-b40d-478c-8adf-683a53baba83',
#  20: 'ad52fa02-0806-47ee-a5d8-d42a5a2297fa',
#  21: '3d90d51c-5950-4374-b210-3804dc4aa96b',
#  22: '414acb9d-c725-459c-9930-9f60a84625d4',
#  23: 'e586389b-30f5-4cdc-a0c1-8f52b63f1859',
#  24: 'abc256a2-a32a-4d43-a194-8e47b819c78c',
#  25: 'e28021dc-3b88-4b40-89ef-81a25c249dc5',
#  26: '195fd4a5-b677-4b4c-8139-df7af4fbf53e',
#  27: 'b12d827d-fadf-4f71-bc77-1d2c5000843e',
#  28: 'de43be8a-69d7-4ae1-8d5d-8befe70d6f00',
#  29: 'ada46e85-53ff-4d68-b7d0-41fd888def73',
#  30: '5ca29e08-7762-43eb-9fcf-a8567ac3fc27',
#  31: '41cd355d-70df-4bbe-8f05-bb555fb85916',
#  32: '13c196b4-b5a4-44e5-94e9-5ae5d74d1d28',
#  33: 'c48eb39b-6217-4a3e-896c-83e4b8e4e5a6',
#  34: 'f9396cc2-d273-421c-8462-f17a96969390',
#  35: '1ae45816-0d0c-4db4-90fe-4b2e84527a07',
#  36: 'a6f215b6-d668-4ff1-84d2-eb9ff723ea2e',
#  37: 'ee8fc061-7447-46b9-8b80-be0de550fa70',
#  38: '4ad48535-80f9-41b5-a610-fc62aeebfb15',
#  39: 'd029a90e-6937-4c35-bd0a-18a0afcad3ce',
#  40: '030ac93f-4b4e-4f26-98fd-9b7ce47ff122',
#  41: 'c6eb9736-030b-4b81-9d73-8044f440032c',
#  42: 'ac6471ff-9d2b-43d5-a9d9-eb221d32b9a7',
#  43: '7fc234df-8cad-45f1-96c1-bc0422f75d35',
#  44: '19c7456e-202f-467e-b3fc-ed191ae6c73e',
#  45: '85fe9256-7200-4eec-ab7d-f45449be9f6d',
#  46: '5a2d9447-79d0-4773-9c93-d4af8b88368b',
#  47: '1f1a7526-bbb7-4f15-ac02-84830fb5698f',
#  48: 'ea9344ac-e3e4-4809-bdd0-f2a0aaa83548',
#  49: '1e594a1a-e4b4-49c5-ba28-0df379b94fb7',
#  50: '912b50df-0e3b-4e91-b60b-102525ddbc65',
#  51: 'f34f01e0-f38b-4e8f-a472-a81ed1b4bcf4',
#  52: '0c56c83b-526b-4702-b58e-a3374876ce5f',
#  53: '738e2abf-5db4-46d4-89cf-de3fb0db32ed',
#  54: '13f36b0d-aff9-4aef-8472-09c7a9869630',
#  55: 'bc062f68-5a15-4d90-bada-b5f85ad8f6b7',
#  56: '11d5b654-a403-4ee4-b24d-48221a990db7',
#  57: '5572deee-f2b5-459c-b1e9-8afcf2809a42',
#  58: '14077d1e-6967-4eb4-b2bd-f3b2a3ce54aa',
#  59: '3c812d82-b207-46a5-ad60-da157057412c',
#  60: '899da55b-ffc3-431a-a4a1-31592657daad',
#  61: 'fbe03221-6b6f-4d8d-81c9-c818580db6bb',
#  62: '711f1ab4-6cae-4ecc-99c8-7bd7cbfcc735',
#  63: '112d4252-8854-4165-b6ea-ca2ecaab3b71',
#  64: 'caac8873-02c2-4e84-9487-c208488c2f7a',
#  65: 'a084b972-3e5b-4935-858e-63cb9399e586',
#  66: '7ef0b4a9-8a95-49cd-80fe-1d8e3bdc66c3',
#  67: '557c0a50-328b-405d-9dc0-b85944e0fba0',
#  68: 'f3c1f2f0-afcb-418d-b957-8b87fb02bd15',
#  69: 'e63393f6-383f-40d4-b6c9-150f40defc4a',
#  70: 'd742c992-49b2-40cb-b048-3fa1d5f83ebb',
#  71: '55447783-6d74-4942-9f10-f758f94cb790',
#  72: '8ab655b3-5ea9-4951-9958-23e2893399f5',
#  73: '0c59e057-c399-47e2-bef3-cdf7f7d5488c',
#  74: '3d202149-8a31-42f2-910e-2f347bd0300b',
#  75: '246ec106-17db-48c9-9b8b-4a5565d88f27',
#  76: '09a72c6d-5009-449e-a212-6568a173794c',
#  77: 'e6e2fbc0-4252-42ed-adc9-dbe3d5ab88b3',
#  78: 'a2323aa9-a18f-4133-bad9-31e46846c6e2',
#  79: '1d9fe2b6-5d85-4c83-a648-b71da0d74b98',
#  80: 'fc2ef7b3-62f5-4b39-a1b5-5bfcbe7b0a8f',
#  81: '6bf4d4bf-5656-4be9-b3c0-4706a337cdeb',
#  82: '94b2f036-66a3-4d24-b7af-9947f9f8575f',
#  83: 'b2a986a1-88dc-480e-8414-bcadfac8eda8',
#  84: '096e453b-ebda-421a-80f7-d02268c02d2c',
#  85: '90fed0ec-030f-492f-8fc8-e1cafd91e48f',
#  86: 'a5f2b11d-8ed0-4934-ba54-6679c557b6aa',
#  87: 'd509705e-f698-466c-94af-c9540d0623a6',
#  88: '89ef5cc6-045b-4543-86c1-ef79a53fb80c',
#  89: 'db773716-8bdb-410e-954e-03df27141c3a',
#  90: '741bb2f0-e11a-4959-bb18-a38d6b3147ad',
#  91: '6eddba89-de5e-49d2-84e9-408723d25591',
#  92: 'c820308c-46ba-4738-9fb4-991df5c076b1',
#  93: '15a09f8e-8a3b-4229-b391-bd01bcac241e',
#  94: '4fd81466-a72e-4323-8239-85e0ad36cb6b',
#  95: 'b0e16cec-80a2-4a3d-8dff-071af802800a',
#  96: '390951c1-af5e-4186-b95d-a843067b723f',
#  97: '2df44791-34d2-487d-ab24-90ac0a4b8588',
#  98: '1b81b3cf-425e-472b-ba0b-ee4e9c9f3e05',
#  99: '48a04a6b-bc7d-42e2-bf83-a81d5d037647',
#  100: 'a58b06ab-ae8f-4494-ba90-b2a5b88c8afc',
#  101: '03740abe-a23e-483c-a0a7-ef42e48e9334',
#  102: 'ac3d1a4a-3c85-41d3-ad98-6cfa66e395b7',
#  103: 'c7cdc9f9-c364-48f4-9980-550aa02bd578',
#  104: 'a81aba57-50e0-4015-bf3a-6330f84f3f0e',
#  105: '77c36ac6-1af2-481c-a8f1-ad7ae06de144',
#  106: '33a318a8-0bd2-40d8-9aa3-2516487a5a98',
#  107: 'e97eace9-97b1-4aa0-a232-c716c1f98172',
#  108: '108512cf-f9a2-4485-929d-1933e6d5453e',
#  109: 'b47f2a4b-6123-4a5d-bfe0-5a6e70b92d65',
#  110: 'e6c97225-eebd-497c-99a6-5aaa17459415',
#  111: '089557b1-8ccd-495f-803e-239bdc1f0bcd',
#  112: '3d111a9a-e81b-4849-8f56-0048e9c81108',
#  113: 'f430981e-ddc2-45d4-8dca-f7fd4ec67d64',
#  114: 'f3f83098-e0f2-4011-acab-16ac25154a18',
#  115: 'e7d82250-14e3-48f5-85af-f2b19fe90434',
#  116: 'e524c68c-b7b4-43e2-8192-fe55a6b15c03',
#  117: '33283f96-c120-4a1b-8ebb-a5f93a2d71bc',
#  118: 'e3467ca3-af94-4748-ae02-a499eea4b92e',
#  119: 'a63b18cd-db71-488e-a1dd-6c6232c1d3cd',
#  120: '115d7485-8217-43d2-977c-4f4b0bc27f89',
#  121: '3c4111f1-af0c-4eb0-8168-d6d2f82fff38',
#  122: 'c7dc7c70-e8b0-428b-983f-c3e4242bcb99',
#  123: '4b68d08a-5ceb-4f04-abeb-a89fa8cc8d82',
#  124: 'df68d142-96cb-4376-880d-3b77f5924ab6',
#  125: '34d7e431-74d5-4f52-aaf2-e18704fd78cf',
#  126: '14ff42e7-a33f-4886-98aa-0ca6c69d73d6',
#  127: 'a0ebd982-6e43-4d25-b431-2900ed3032b3',
#  128: 'f0528d39-6642-46a3-9a93-2371673404c3',
#  129: 'afaf582f-4b19-4ed2-9d07-7ab516974638',
#  130: '663a34ed-f32c-49b7-b025-37fac624f17a',
#  131: '559b3346-b35c-4e8e-b2f0-bcd7b528d1b7',
#  132: '999446e6-cf7d-4357-94b3-8a3c11d4ea01',
#  133: 'f80c079a-08a7-4400-8c21-fc62c99ac8cc',
#  134: '4c449ae9-bcb7-414c-b018-4f08523a1d71',
#  135: '57a6f8be-a588-4399-b652-aca4105b5925',
#  136: '39ca9ae0-9a7a-4bdd-95e6-43643ecfdf9c',
#  137: 'bf50fe72-07dc-4d5c-80d2-c11a6744f874',
#  138: 'e96a8946-72c2-48b1-aa3d-bf08a3c29c35',
#  139: '7d6c1ae2-47c4-4ac5-8b5c-4e7d11a95c15',
#  140: 'c75f66e6-d4fc-4397-bf16-ef453e42370f',
#  141: '6988ea2e-c218-4090-95f1-06e0392ae756',
#  142: '714d9f81-9f0a-4274-944a-2f2f9d64d97d',
#  143: 'a337a15a-e6b4-402c-ae53-29b7def88e65',
#  144: '5c39d5b9-2537-4fc7-8f17-6aaf22bfa06c',
#  145: 'a327acf5-3594-4978-943c-8eb34aa1c712',
#  146: '9036e4b3-a6b4-4605-8196-914cea853a65',
#  147: '03699beb-c16e-474d-b640-aa54f5df0ca4',
#  148: 'dd51bd88-e54b-496e-81c2-ed517257a921',
#  149: 'dfeb9ee5-6ed3-488a-a8d3-14fb9517fd34',
#  150: '54f7f09f-9865-4d93-97ec-4ff496593253',
#  151: '6df18091-607e-4de7-9073-3ad9ba6fe781',
#  152: 'bee1e791-5782-4d43-9e4c-739a62898327',
#  153: '8c82285a-9666-4d19-b9ae-77f6ee6d39d5',
#  154: '64e26ff3-4667-4a75-bb25-a6287f3b4c95',
#  155: 'd6f7b493-3e09-46a7-9cf3-03c31e8f57c0',
#  156: '8e956601-0f30-409e-a07e-6e5b7809604d',
#  157: '15587d1a-8fef-45b1-8b89-96fe982b390b',
#  158: '01c2f3d5-eabc-4f0a-9d5e-25afcfa42de0',
#  159: '386c8fdc-efb9-42ce-90c4-2f7d662039e9',
#  160: 'e653fb8b-5025-4c14-8c18-22979983002d',
#  161: '9a7ca04b-d96c-4b38-896f-9d88dbba13ab',
#  162: 'b2eadeeb-9916-4813-85bd-b9d0f969ccfa',
#  163: 'e3005ca7-6af9-4be9-a26e-7594f02181e7',
#  164: 'fddc9511-8912-45d7-bf51-ba50c2483bda',
#  165: 'bb676a99-ded6-4d5e-9cf1-49a2dffd3448',
#  166: 'e2268fd5-5951-4908-b740-382bb34595db',
#  167: 'b6676381-1369-44b5-8c17-1fcc48069e7f'}

# %%
vector_store.get_by_ids(['bb676a99-ded6-4d5e-9cf1-49a2dffd3448'])
# Out:
# [Document(id='bb676a99-ded6-4d5e-9cf1-49a2dffd3448', metadata={}, page_content="from the systems like all right how do i explain to the excuse me exactly all right let me i don't have time to explain uh maybe i'll draw you a picture that it is i mean how do you even begin um to answer that question well i think it would um what would you what would you think the answer could possibly look like i think it could it could start looking like uh uh more fundamental explanations of physics would be the beginning you know more careful specification of that taking you walking us through by the hand as to what one would do to maybe prove those things out maybe giving you glimpses of what things you totally missed in the physics of today exactly just here here's glimpses of no like there's a much uh a much more elaborate world or a much simpler world or something a much deeper maybe simpler explanation yes of things right than the standard model of physics which we know doesn't work but we still keep adding to so um and and that's how i think the beginning of an")]

# %% [markdown]
# # Step 2 - Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x7f608e33e290>, search_kwargs={'k': 4})

# %%
retriever.invoke('What is deepmind')
# Out:
# [Document(id='caac8873-02c2-4e84-9487-c208488c2f7a', metadata={}, page_content="and how it works this is tough to uh ask you this question because you probably will say it's everything but let's let's try let's try to think to this because you're in a very interesting position where deepmind is the place of some of the most uh brilliant ideas in the history of ai but it's also a place of brilliant engineering so how much of solving intelligence this big goal for deepmind how much of it is science how much is engineering so how much is the algorithms how much is the data how much is the hardware compute infrastructure how much is it the software computer infrastructure yeah um what else is there how much is the human infrastructure and like just the humans interact in certain kinds of ways in all the space of all those ideas how much does maybe like philosophy how much what's the key if um uh if if you were to sort of look back like if we go forward 200 years look back what was the key thing that solved intelligence is that ideas i think it's a combination first"),
#  Document(id='190a8760-5bba-421a-9ad4-3a47002db43d', metadata={}, page_content="the following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough"),
#  Document(id='0c59e057-c399-47e2-bef3-cdf7f7d5488c', metadata={}, page_content="ambitious as trying to solve intelligence and you're you're you know it's blue sky research no one knows how to do it you you you need to use any evidence or any source of information you can to help guide you in the right direction or give you confidence you're going in the right direction so so that that was one reason we pushed so hard on that and that's and just going back to your early question about organization the other big thing that i think we innovated with at deepmind to encourage invention and and uh and innovation was the multi-disciplinary organization we built and we still have today so deepmind originally was a confluence of the of the most cutting-edge knowledge in neuroscience with machine learning engineering and mathematics right and and gaming and then since then we built that out even further so we have philosophers here and and uh by you know ethicists but also other types of scientists physicists and so on um and that's what brings together i tried to build a"),
#  Document(id='3d90d51c-5950-4374-b210-3804dc4aa96b', metadata={}, page_content="used of ai is in deep mind from the beginning which is using games as a testing ground for proving out ai algorithms and developing ai algorithms and that was a that was a sort of um a core component of our vision at the start of deepmind was that we would use games very heavily uh as our main testing ground certainly to begin with um because it's super efficient to use games and also you know it's very easy to have metrics to see how well your systems are improving and what direction your ideas are going in and whether you're making incremental improvements and because those games are often rooted in something that humans did for a long time beforehand there's already a strong set of rules like it's already a damn good benchmark yes it's really good for so many reasons because you've got you've got you've got clear measures of how good humans can be at these things and in some cases like go we've been playing it for thousands of years um and and uh often they have scores or at least")]

# %% [markdown]
# Step 3 - Augmentation

# %%
question          = "is the topic of nuclear fusion discussed in this video? if yes then what was discussed"
retrieved_docs    = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='b0e16cec-80a2-4a3d-8dff-071af802800a', metadata={}, page_content="in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of"),
#  Document(id='4fd81466-a72e-4323-8239-85e0ad36cb6b', metadata={}, page_content='that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double'),
#  Document(id='1b81b3cf-425e-472b-ba0b-ee4e9c9f3e05', metadata={}, page_content="so we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and"),
#  Document(id='15a09f8e-8a3b-4229-b391-bd01bcac241e', metadata={}, page_content="like room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so")]

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs) # join 4 result
context_text
# Out:
# "in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of\n\nthat i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double\n\nso we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and\n\nlike room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so"

# %%
prompt = PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context', 'question']
)

# %%
#Augmentation
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double checked with the team we were going to use carefully and safely i was impressed they managed to persuade them to let us use it and um and it's a it's an amazing test reactor they have there and they try all sorts of pretty crazy experiments on it and um the the the what we tend to look at is if we go into a new domain like fusion what are all the bottleneck problems uh like thinking from first principles you know what are all the bottleneck problems that are still stopping fusion working today and then we look at we you know we get a fusion expert to tell us and then we look at those bottlenecks and we look at the ones which ones are amenable to our ai methods today yes right and and and then and would be interesting from a research perspective from our point of view from an ai point of\n\nthat i would like to i think could be very transformative if we helped accelerate and uh really interesting problems scientific challenges in of themselves this is energy so energy yes exactly so energy and climate so we talked about disease and biology as being one of the biggest places i think ai can help with i think energy and climate uh is another one so maybe they would be my top two um and fusion is one one area i think ai can help with now fusion has many challenges mostly physics material science and engineering challenges as well to build these massive fusion reactors and contain the plasma and what we try to do whenever we go into a new field to apply our systems is we look for um we talk to domain experts we try and find the best people in the world to collaborate with um in this case in fusion we we collaborated with epfl in switzerland the swiss technical institute who are amazing they have a test reactor that they were willing to let us use which you know i double\n\nso we with this problem and we published it in a nature paper last year uh we held the fusion that we held the plasma in specific shapes so actually it's almost like carving the plasma into different shapes and control and hold it there for the record amount of time so um so that's one of the problems of of fusion sort of um solved so i have a controller that's able to no matter the shape uh contain it continue yeah contain it and hold it in structure and there's different shapes that are better for for the energy productions called droplets and and and so on so um so that was huge and now we're looking we're talking to lots of fusion startups to see what's the next problem we can tackle uh in the fusion area so another fascinating place in a paper title pushing the frontiers of density functionals by solving the fractional electron problem so you're taking on modeling and simulating the quantum mechanical behavior of electrons yes um can you explain this work and can ai model and\n\nlike room temperature superconductors or something on my list one day i'd like to like you know have an ai system to help build better optimized batteries all of these sort of mechanical things mr i think a systematic sort of search could be uh guided by a model could be um could be extremely powerful so speaking of which you have a paper on nuclear fusion uh magnetic control of tokamak plasmas to deep reinforcement learning so you uh you're seeking to solve nuclear fusion with deep rl so it's doing control of high temperature plasmas can you explain this work and uh can ai eventually solve nuclear fusion it's been very fun last year or two and very productive because we've been taking off a lot of my dream projects if you like of things that i've collected over the years of areas of science that i wou ...

# %% [markdown]
# # Step 4 - Generation

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBMuYZT9NEjPlwg_7QXFK6k7QvHy04rRa4"

# %%
llm = ChatGoogleGenerativeAI(model='gemini-1.5-pro')

# %%
answer = llm.invoke(final_prompt)
print(answer.content)
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 12
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# /tmp/ipython-input-55-930803179.py in <cell line: 0>()
# ----> 1 answer = llm.invoke(final_prompt)
#       2 print(answer.content)
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in invoke(self, input, config, code_execution, stop, **kwargs)
#    1253                 )
#    1254
# -> 1255         return super().invoke(input, config, stop=stop, **kwargs)
#    1256
#    1257     def _get_ls_params(
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     370         return cast(
#     371             "ChatGeneration",
# --> 372             self.generate_prompt(
#     373                 [self._convert_input(input)],
#     374                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     955     ) -> LLMResult:
#     956         prompt_messages = [p.to_messages() for p in prompts]
# --> 957         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     958
#     959     @override
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     774             try:
#     775                 results.append(
# --> 776                     self._generate_with_cache(
#     777                         m,
#     778                         stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020             result = generate_from_stream(iter(chunks))
#    1021         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022             result = self._generate(
#    1023                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1024             )
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1340             tool_choice=tool_choice,
#    1341         )
# -> 1342         response: GenerateContentResponse = _chat_with_retry(
#    1343             request=request,
#    1344             **kwargs,
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(generation_method, **kwargs)
#     208             raise e
#     209
# --> 210     return _chat_with_retry(**kwargs)
#     211
#     212
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     336             copy = self.copy()
#     337             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338             return copy(f, *args, **kw)
#     339
#     340         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(**kwargs)
#     206             ) from e
#     207         except Exception as e:
# --> 208             raise e
#     209
#     210     return _chat_with_retry(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(**kwargs)
#     190     def _chat_with_retry(**kwargs: Any) -> Any:
#     191         try:
# --> 192             return generation_method(**kwargs)
#     193         # Do not retry for these errors.
#     194         except google.api_core.exceptions.FailedPrecondition as exc:
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     866
#     867         # Send the request.
# --> 868         response = rpc(
#     869             request,
#     870             retry=retry,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     212             original_timeout,
#     213         )
# --> 214         raise final_exc from source_exc
#     215     if on_error_fn is not None:
#     216         on_error_fn(exc)
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
# ---> 78             raise exceptions.from_grpc_error(exc) from exc
#      79
#      80     return error_remapped_callable
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ]

# %% [markdown]
# # Building a Chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
# Testing
parallel_chain.invoke('who is Demis')
# Out:
# {'context': "to get world peace because there's also other corrupting things like wanting power over people and this kind of stuff which is not necessarily satisfied by by just abundance but i think it will help um and i think uh but i think ultimately ai is not going to be run by any one person or one organization i think it should belong to the world belong to humanity um and i think maybe many there'll be many ways this will happen and ultimately um everybody should have a say in that do you have advice for uh young people in high school and college maybe um if they're interested in ai or interested in having a big impact on the world what they should do to have a career they can be proud of her to have a life they can be proud of i love giving talks to the next generation what i say to them is actually two things i i think the most important things to learn about and to find out about when you're when you're young is what are your true passions is first of all there's two things one is find\n\nthe following is a conversation with demus hasabis ceo and co-founder of deepmind a company that has published and builds some of the most incredible artificial intelligence systems in the history of computing including alfred zero that learned all by itself to play the game of gold better than any human in the world and alpha fold two that solved protein folding both tasks considered nearly impossible for a very long time demus is widely considered to be one of the most brilliant and impactful humans in the history of artificial intelligence and science and engineering in general this was truly an honor and a pleasure for me to finally sit down with him for this conversation and i'm sure we will talk many times again in the future this is the lex friedman podcast to support it please check out our sponsors in the description and now dear friends here's demis hassabis let's start with a bit of a personal question am i an ai program you wrote to interview people until i get good enough\n\nof deep mind just as a human being let me ask you about this one particular anecdotal evidence of the google engineer who made a comment or believed that there's some aspect of a language model the lambda language model that exhibited sentience so you said you believe there might be a responsibility to build systems that are not essential and this experience of a particular engineer i think i'd love to get your general opinion on this kind of thing but i think it will happen more and more and more which uh not when engineers but when people out there that don't have an engineering background start interacting with increasingly intelligent systems we anthropomorphize them they they start to have deep impactful um interactions with us in a way that we miss them yeah when they're gone and we sure feel like they're living entities self-aware entities and maybe even we project sentience onto them so what what's your thought about this particular uh system was is uh have you ever met a\n\nthat are amazingly smart at certain things like maybe playing go and chess and other things but they don't feel at all in any shape or form conscious in the way that you know you do to me or i do to you and um and i think actually building ai is uh these intelligent constructs uh is one of the best ways to explore the mystery of consciousness to break it down because um we're going to have devices that are pretty smart at certain things or capable of certain things but potentially won't have any semblance of self-awareness or other things and in fact i would advocate if there's a choice building systems in the first place ai systems that are not conscious to begin with uh are just tools um until we understand them better and the capabilities better so on that topic just not as the ceo of deep mind just as a human being let me ask you about this one particular anecdotal evidence of the google engineer who made a comment or believed that there's some aspect of a language mo ...
#  'question': 'who is Demis'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summarize the video')
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 10
# }
# ].
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# /tmp/ipython-input-40-2431188878.py in <cell line: 0>()
# ----> 1 main_chain.invoke('Can you summarize the video')
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3045                         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046                     else:
# -> 3047                         input_ = context.run(step.invoke, input_, config)
#    3048         # finish the root run
#    3049         except BaseException as e:
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in invoke(self, input, config, code_execution, stop, **kwargs)
#    1253                 )
#    1254
# -> 1255         return super().invoke(input, config, stop=stop, **kwargs)
#    1256
#    1257     def _get_ls_params(
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     370         return cast(
#     371             "ChatGeneration",
# --> 372             self.generate_prompt(
#     373                 [self._convert_input(input)],
#     374                 stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     955     ) -> LLMResult:
#     956         prompt_messages = [p.to_messages() for p in prompts]
# --> 957         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     958
#     959     @override
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     774             try:
#     775                 results.append(
# --> 776                     self._generate_with_cache(
#     777                         m,
#     778                         stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020             result = generate_from_stream(iter(chunks))
#    1021         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022             result = self._generate(
#    1023                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1024             )
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1340             tool_choice=tool_choice,
#    1341         )
# -> 1342         response: GenerateContentResponse = _chat_with_retry(
#    1343             request=request,
#    1344             **kwargs,
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(generation_method, **kwargs)
#     208             raise e
#     209
# --> 210     return _chat_with_retry(**kwargs)
#     211
#     212
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     336             copy = self.copy()
#     337             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338             return copy(f, *args, **kw)
#     339
#     340         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.11/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(**kwargs)
#     206             ) from e
#     207         except Exception as e:
# --> 208             raise e
#     209
#     210     return _chat_with_retry(**kwargs)
#
# /usr/local/lib/python3.11/dist-packages/langchain_google_genai/chat_models.py in _chat_with_retry(**kwargs)
#     190     def _chat_with_retry(**kwargs: Any) -> Any:
#     191         try:
# --> 192             return generation_method(**kwargs)
#     193         # Do not retry for these errors.
#     194         except google.api_core.exceptions.FailedPrecondition as exc:
#
# /usr/local/lib/python3.11/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     866
#     867         # Send the request.
# --> 868         response = rpc(
#     869             request,
#     870             retry=retry,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     212             original_timeout,
#     213         )
# --> 214         raise final_exc from source_exc
#     215     if on_error_fn is not None:
#     216         on_error_fn(exc)
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.11/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
# ---> 78             raise exceptions.from_grpc_error(exc) from exc
#      79
#      80     return error_remapped_callable
#
# ResourceExhausted: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. [violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-1.5-pro"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , retry_delay {
#   seconds: 8
# }
# ]
